# %%
import os
from dotenv import load_dotenv
from pathlib import Path
import pandas

import json
import mysql.connector
from datetime import datetime
from services.db_ops import helpers as db_hlp, query_factory as qf, db as db_ops
from services.ai_chat import agents
from services.pql.translate import  PQLTranslator


env_path = Path('../services/docker/.env')
load_dotenv(dotenv_path=env_path)
# Out:
# True

# %%
table_name = "Orders_oct_16_2024_20_00"
eval_name = "eval_oct_16_2024_20_00"
reset_data = False
eval_config = {}
with open('services/pql/eval/eval_config.json', 'r') as file:
    eval_config = json.load(file)
    eval_config = eval_config.get(eval_name)

# %%
print(eval_config['question_generation_prompt'])
# Out:
# This is data for testing an app to generate SQL to answer user queries. Using these data and questions you generate, large language models will generate SQL and be evaluated on the result. The target audience for the app is data analysts. The scope is business data, so the target audience will be doing business analysis. Currently the app answers only single-value questions (questions that can be answered by single value like a KPI instead of multiple values like a chart). The app supports 5 data types: string, integer, float, date, and null. To evaluate the app, we need to generate questions that can be answered by SQL queries on this data. The questions should be in different complexities - from level_0 to level_5. Please generate three valid questions of each complexity level and three invalid questions of each complexity level. Please provide the the questions in JSON. For each, use {question: ---, expected_value: ---} format, and leave expected_value empty

# %%
mysql_root_user = os.getenv("MYSQL_ROOT_USER")
mysql_root_password = os.getenv("MYSQL_ROOT_PASSWORD")
mysql_database = os.getenv("MYSQL_DATABASE")

openai_key = os.getenv("OPENAI_API_KEY")
openai_model = os.getenv(eval_config["model"])
openai_assistant_id = os.getenv("OPEN_AI_ANALYSIS_CHAT_ASSISTANT_ID")

# %%
mydb = mysql.connector.connect(
    host="localhost",
    user=mysql_root_user,
    password=mysql_root_password,
    database=mysql_database
)

mycursor = mydb.cursor()

# %%
df = pandas.read_csv(f"services/pql/eval/eval_data/{table_name}.csv")
df = df.where(pandas.notnull(df), None) # Replace NaN with None for MySQL
data = df.to_dict(orient='records')

table_meta = None
with open('services/pql/eval/eval_data/data_config.json', 'r') as file:
    _all_columns = json.load(file)
    table_meta = _all_columns.get(table_name)
    columns = table_meta.get("columns")

assert columns is not None, "Columns not loaded"
assert isinstance(columns, dict), "Columns is not a dict"

columns_with_dtype = []
for k, v in columns.items():
    columns_with_dtype.append((k, db_hlp.DATA_TYPE_MAP[v['dtype']]))

# %%
# Get the table and column information
_table_information = f"""Table information:\n
Table name: {table_name if eval_config['table_name_provided'] else ''}\n
Table description: {table_meta['table_description'] if eval_config['table_descrition_provided'] else ''}\n
"""

_column_information = "Column information:\n"
for k, v in columns.items():
    _column_information += f"""Column name: {k if eval_config['column_names_provided'] else ''}\n
    Column description: {v['description'] if eval_config['column_descriptions_provided'] else ''}\n
    Column data type: {v['dtype'] if eval_config['column_dtypes_provided'] else ''}\n
"""

# %%
if reset_data:
    # create table
    query = f'''
        DROP TABLE IF EXISTS `{table_name}`;
    '''
    mycursor.execute(query)
    mydb.commit()

    query = qf.generate_create_table_sql(table_name, columns_with_dtype)[0]
    mycursor.execute(query)
    mydb.commit()

    # insert data
    column_formats = {}
    for k, v in columns.items():
        column_formats[k] = v['format']
    _query, _inputs = qf.generate_insert_data_sql(table_name, data, column_formats)
    mycursor.execute(_query, _inputs)
    mydb.commit()

# %%
eval_result_data_name = datetime.now().isoformat().split(".")[0]
eval_result_file_name = f"services/pql/eval/eval_results/{eval_result_data_name}.json"
runs = {
    "pql_version": "v0.1.0",
    "eval_time": datetime.now().isoformat(),
    "eval_config": eval_config,
    "assistant": openai_assistant_id,
    "runs": {
        "simple_questions": [],
        "medium_questions": [],
        "complex_questions": []
    }
}

# %%
valid_questions = table_meta.get("user_questions").get("valid_questions")

# %%
for level in list(valid_questions.keys()):
    for q_info in valid_questions[level]:
        question_category = "valid_questions"
        question = q_info.get("question")
        expected_value = q_info.get("expected_value")
        
        chat_id = f"{table_name}_{level}_{q_info.get('index')}"
        openai_agent = agents.OpenAIAnalysisAgent(user_message=question, chat_id=chat_id, thread_id=chat_id)
        openai_agent.start_new_thread()
        result = openai_agent.send_message(table_informaiton=_table_information, column_informaion=_column_information)

        if result.get("success", None) == True:
            # get sql
            _pql = result.get("message")

            assert _pql is not None, "PQL not generated"
            assert isinstance(_pql, dict), "PQL is not a dict"

            _sql_translator = PQLTranslator(pql=_pql)
            _sql_translator.translate()
            result["sql"] = _sql_translator.translated_pql

            # Execute the SQL
            query = result["sql"]
            _sql_executor = db_ops.TranslatedPQLExecution(translated_sql=query)
            print(_sql_executor.translated_sql)

            try:
                _sql_exec_status = True
                mycursor.execute(_sql_executor.translated_sql)
                _sql_exec_result = db_hlp.dictfetchall(mycursor)
            except Exception as e:
                _sql_exec_status = False
                _sql_exec_result = str(e)

            result["sql_execution_status"] = _sql_exec_status
            result["sql_execution_result"] = _sql_exec_result
            result["sql_execution_value"] = list(_sql_exec_result[0].values())[0] if _sql_exec_status else None
            result["expected_value"] = q.get("expected_value")


        runs["runs"][q_type].append(result)
# Out:
# Full agent response: [Message(id='msg_5KirtQKVthyTBEo5758NtZtW', assistant_id='asst_1Z7wPRRU5nxP7P7BYWyXX25m', attachments=[], completed_at=None, content=[TextContentBlock(text=Text(annotations=[], value='```json\n{\n    "VERSION": "v0.1.0",\n    "NAME": "Total Price",\n    "DESCRIPTION": "The total price of all orders. Calculated by taking the sum of the price column",\n    "TABLE": "Orders_oct_12_2024_20_00",\n    "BLOCKS": [\n        {\n            "SCALAR_BLOCK": {\n                "COLUMNS": ["price"],\n                "OPERATOR": "COLUMN_SUM",\n                "AS": "total_price"\n            }\n        }\n    ]\n}\n```'), type='text')], created_at=1728767305, incomplete_at=None, incomplete_details=None, metadata={}, object='thread.message', role='assistant', run_id='run_4Z3m0gPIKcmIcX0sthith7MC', status=None, thread_id='thread_o0NxadqORA2zoDzyswKwNjAq'), Message(id='msg_nuBAWwupEYlR0vU3pxRk3dSK', assistant_id=None, attachments=[], completed_at=None, content=[TextContentBlock(text=Text(annotations=[], value='Please provide me with a PQL in JSON format that can answer this question, keep it in one JSON and do not add any other text:The following is the table information: Table information:\n\nTable name: Orders_oct_12_2024_20_00\n\nTable description: \n\n\nThe following is the column information in the table: Column information:\nColumn name: order_id\n\n    Column description: \n\n    Column data type: string\n\nColumn name: quantity\n\n    Column description: \n\n    Column data type: float\n\nColumn name: date\n\n    Column description: \n\n    Column data type: date\n\nColumn name: price\n\n    Column description: \n\n    Column data type: float\n\nColumn name: material\n\n    Column description: \n\n    Column data type: string\n\nColumn name: customer\n\n    Column description: \n\n    Column data type: string\n\n\nWhat is the total price?'), type='text')], created_at=1728767301, incomplete_at=None, incomplete_details=None, metadata={}, object='thread.message', role='user', run_id=None, status=None, thread_id='thread_o0NxadqORA2zoDzyswKwNjAq')]
# Current agent response to extract: ```json
# {
#     "VERSION": "v0.1.0",
#     "NAME": "Total Price",
#     "DESCRIPTION": "The total price of all orders. Calculated by taking the sum of the price column",
#     "TABLE": "Orders_oct_12_2024_20_00",
#     "BLOCKS": [
#         {
#             "SCALAR_BLOCK": {
#                 "COLUMNS": ["price"],
#                 "OPERATOR": "COLUMN_SUM",
#                 "AS": "total_price"
#             }
#         }
#     ]
# }
# ```
# Extracted JSON: {'VERSION': 'v0.1.0', 'NAME': 'Total Price', 'DESCRIPTION': 'The total price of all orders. Calculated by taking the sum of the price column', 'TABLE': 'Orders_oct_12_2024_20_00', 'BLOCKS': [{'SCALAR_BLOCK': {'COLUMNS': ['price'], 'OPERATOR': 'COLUMN_SUM', 'AS': 'total_price'}}]}
# Validating PQL: {'VERSION': 'v0.1.0', 'NAME': 'Total Price', 'DESCRIPTION': 'The total price of all orders. Calculated by taking the sum of the price column', 'TABLE': 'Orders_oct_12_2024_20_00', 'BLOCKS': [{'SCALAR_BLOCK': {'COLUMNS': ['price'], 'OPERATOR': 'COLUMN_SUM', 'AS': 'total_price'}}]}
# PQL validation errors: []
# PQL: {'VERSION': 'v0.1.0', 'NAME': 'Total Price', 'DESCRIPTION': 'The total price of all orders. Calculated by taking the sum of the price column', 'TABLE': 'Orders_oct_12_2024_20_00', 'BLOCKS': [{'SCALAR_BLOCK': {'COLUMNS': ['price'], 'OPERATOR': 'COLUMN_SUM', 'AS': 'total_price'}}]}
# WITH
# `latest_table_1ad9b55165074b578cc34c3b02fb52a6` AS (
# SELECT * FROM `Orders_oct_12_2024_20_00`
# )
#             SELECT SUM(`price`) AS `total_price`
#             FROM `latest_table_1ad9b55165074b578cc34c3b02fb52a6`;
#
# Full agent response: [Message(id='msg_0pduvZwyzRFayrm5qd52pJ7O', assistant_id='asst_1Z7wPRRU5nxP7P7BYWyXX25m', attachments=[], completed_at=None, content=[TextContentBlock(text=Text(annotations=[], value='```json\n{\n    "VERSION": "v0.1.0",\n    "NAME": "Total Price of Orders with Quantity Greater than 10",\n    "DESCRIPTION": "Calculate the total price of orders where the quantity is greater than 10.",\n    "TABLE": "Orders_oct_12_2024_20_00",\n    "BLOCKS": [\n        {\n            "FILTER_BLOCK": {\n                "COLUMNS": ["quantity"],\n                "COMPARISON_OPERATOR": ">",\n                "VALUE": 10\n            }\n        },\n        {\n            "SCALAR_BLOCK": {\n                "COLUMNS": ["price"],\n                "OPERATOR": "COLUMN_SUM",\n                "AS": "total_price"\n            }\n        }\n    ]\n}\n```'), type='text')], created_at=1728767313, incomplete_at=None, incomplete_details=None, metadata={}, object='thread.message', role='assistant', run_id='run_3bBKMEc6LUFlvzG3L4YLZyE5', status=None, thread_id='thread_8WlUv59yUom38vEl8qD2ROPZ'), Message(id='msg_nwfNz5GgfqBIrQ973uXk9gsh', assistant_id=None, attachments=[], completed_at=None, content=[TextContentBlock(text=Text(annotations=[], value='Please provide me with a PQL in JSON format that can answer this question, keep it in one JSON and do not add any other text:The following is the table information: Table information:\n\nTable name: Orders_oct_12_2024_20_00\n\nTable description: \n\n\nThe following is the column information in the table: Column information:\nColumn name: order_id\n\n    Column description: \n\n    Column data type: string\n\nColumn name: quantity\n\n    Column description: \n\n    Column data type: float\n\nColumn name: date\n\n    Column description: \n\n    Column data type: date\n\nColumn name: price\n\n    Column description: \n\n    Column data type: float\n\nColumn name: material\n\n    Column description: \n\n    Column data type: string\n\nColumn name: customer\n\n    Column description: \n\n    Column data type: string\n\n\nWhat is the total price of orders with quantity greater than 10?'), type='text')], created_at=1728767308, incomplete_at=None, incomplete_details=None, metadata={}, object='thread.message', role='user', run_id=None, status=None, thread_id='thread_8WlUv59yUom38vEl8qD2ROPZ')]
# Current agent response to extract: ```json
# {
#     "VERSION": "v0.1.0",
#     "NAME": "Total Price of Orders with Quantity Greater than 10",
#     "DESCRIPTION": "Calculate the total price of orders where the quantity is greater than 10.",
#     "TABLE": "Orders_oct_12_2024_20_00",
#     "BLOCKS": [
#         {
#             "FILTER_BLOCK": {
#                 "COLUMNS": ["quantity"],
#                 "COMPARISON_OPERATOR": ">",
#                 "VALUE": 10
#             }
#         },
#         {
#             "SCALAR_BLOCK": {
#                 "COLUMNS": ["price"],
#                 "OPERATOR": "COLUMN_SUM",
#                 "AS": "total_price"
#             }
#         }
#     ]
# }
# ```
# Extracted JSON: {'VERSION': 'v0.1.0', 'NAME': 'Total Price of Orders with Quantity Greater than 10', 'DESCRIPTION': 'Calculate the total price of orders where the quantity is greater than 10.', 'TABLE': 'Orders_oct_12_2024_20_00', 'BLOCKS': [{'FILTER_BLOCK': {'COLUMNS': ['quantity'], 'COMPARISON_OPERATOR': '>', 'VALUE': 10}}, {'SCALAR_BLOCK': {'COLUMNS': ['price'], 'OPERATOR': 'COLUMN_SUM', 'AS': 'total_price'}}]}
# Validating PQL: {'VERSION': 'v0.1.0', 'NAME': 'Total Price of Orders with Quantity Greater than 10', 'DESCRIPTION': 'Calculate the total price of orders where the quantity is greater than 10.', 'TABLE': 'Orders_oct_12_2024_20_00', 'BLOCKS': [{'FILTER_BLOCK': {'COLUMNS': ['quantity'], 'COMPARISON_OPERATOR': '>', 'VALUE': 10}}, {'SCALAR_BLOCK': {'COLUMNS': ['price'], 'OPERATOR': 'COLUMN_SUM', 'AS': 'total_price'}}]}
# PQL validation errors: []
# PQL: {'VERSION': 'v0.1.0', 'NAME': 'Total Price of Orders with Quantity Greater than 10', 'DESCRIPTION': 'Calculate the total price of orders where the quantity is greater than 10.', 'TABLE': 'Orders_oct_12_2024_20_00', 'BLOCKS': [{'FILTER_BLOCK': {'COLUMNS': ['quantity'], 'COMPARISON_OPERATOR': '>', 'VALUE': 10}}, {'SCALAR_BLOCK': {'COLUMNS': ['price'], 'OPERATOR': 'COLUMN_SUM', 'AS': 'total_price'}}]}
# filter block
# {'FILTER_BLOCK': {'COLUMNS': ['quantity'], 'COMPARISON_OPERATOR': '>', 'VALUE': 10}}
#
#             `latest_table_7ef39604636545a5b759aacc6380d930` AS (
#                 SELECT *
#                 FROM `latest_table_e7c22428d834437c8f1ed94f24b69614`
#                 WHERE `quantity` > 10
#             )
#          `quantity` > 10 AND
# WITH
# `latest_table_e7c22428d834437c8f1ed94f24b69614` AS (
# SELECT * FROM `Orders_oct_12_2024_20_00`
# ),
#
#             `latest_table_7ef39604636545a5b759aacc6380d930` AS (
#                 SELECT *
#                 FROM `latest_table_e7c22428d834437c8f1ed94f24b69614`
#                 WHERE `quantity` > 10
#             )
#
#             SELECT SUM(`price`) AS `total_price`
#             FROM `latest_table_7ef39604636545a5b759aacc6380d930`;
#
# Full agent response: [Message(id='msg_4ZdGdQSQ1wDDd2XdwdkSwQGh', assistant_id='asst_1Z7wPRRU5nxP7P7BYWyXX25m', attachments=[], completed_at=None, content=[TextContentBlock(text=Text(annotations=[], value='```json\n{\n    "VERSION": "v0.1.0",\n    "NAME": "Total Price of Orders with Quantity > 10 and Price > 100",\n    "DESCRIPTION": "Calculate the total price of orders where the quantity is greater than 10 and the price is greater than 100.",\n    "TABLE": "Orders_oct_12_2024_20_00",\n    "BLOCKS": [\n        {\n            "FILTER_BLOCK": {\n                "COLUMNS": ["quantity", "price"],\n                "COMPARISON_OPERATOR": ">",\n                "VALUE": [10, 100]\n            }\n        },\n        {\n            "SCALAR_BLOCK": {\n                "COLUMNS": ["price"],\n                "OPERATOR": "COLUMN_SUM",\n                "AS": "total_price"\n            }\n        }\n    ]\n}\n```'), type='text')], created_at=1728767321, incomplete_at=None, incomplete_details=None, metadata={}, object='thread.message', role='assistant', run_id='run_gD5k7EfTPmtxZE6gXJg9pc4z', status=None, thread_id='thread_aL9r0TkSyabwqBe8dQaLbOfa'), Message(id='msg_o0IW7RMzu6pOmMb11ENYt3RL', assistant_id=None, attachments=[], completed_at=None, content=[TextContentBlock(text=Text(annotations=[], value='Please provide me with a PQL in JSON format that can answer this question, keep it in one JSON and do not add any other text:The following is the table information: Table information:\n\nTable name: Orders_oct_12_2024_20_00\n\nTable description: \n\n\nThe following is the column information in the table: Column information:\nColumn name: order_id\n\n    Column description: \n\n    Column data type: string\n\nColumn name: quantity\n\n    Column description: \n\n    Column data type: float\n\nColumn name: date\n\n    Column description: \n\n    Column data type: date\n\nColumn name: price\n\n    Column description: \n\n    Column data type: float\n\nColumn name: material\n\n    Column description: \n\n    Column data type: string\n\nColumn name: customer\n\n    Column description: \n\n    Column data type: string\n\n\nWhat is the total price of orders with quantity greater than 10 and price greater than 100?'), type='text')], created_at=1728767318, incomplete_at=None, incomplete_details=None, metadata={}, object='thread.message', role='user', run_id=None, status=None, thread_id='thread_aL9r0TkSyabwqBe8dQaLbOfa')]
# Current agent response to extract: ```json
# {
#     "VERSION": "v0.1.0",
#     "NAME": "Total Price of Orders with Quantity > 10 and Price > 100",
#     "DESCRIPTION": "Calculate the total price of orders where the quantity is greater than 10 and the price is greater than 100.",
#     "TABLE": "Orders_oct_12_2024_20_00",
#     "BLOCKS": [
#         {
#             "FILTER_BLOCK": {
#                 "COLUMNS": ["quantity", "price"],
#                 "COMPARISON_OPERATOR": ">",
#                 "VALUE": [10, 100]
#             }
#         },
#         {
#             "SCALAR_BLOCK": {
#                 "COLUMNS": ["price"],
#                 "OPERATOR": "COLUMN_SUM",
#                 "AS": "total_price"
#             }
#         }
#     ]
# }
# ```
# Extracted JSON: {'VERSION': 'v0.1.0', 'NAME': 'Total Price of Orders with Quantity > 10 and Price > 100', 'DESCRIPTION': 'Calculate the total price of orders where the quantity is greater than 10 and the price is greater than 100.', 'TABLE': 'Orders_oct_12_2024_20_00', 'BLOCKS': [{'FILTER_BLOCK': {'COLUMNS': ['quantity', 'price'], 'COMPARISON_OPERATOR': '>', 'VALUE': [10, 100]}}, {'SCALAR_BLOCK': {'COLUMNS': ['price'], 'OPERATOR': 'COLUMN_SUM', 'AS': 'total_price'}}]}
# Validating PQL: {'VERSION': 'v0.1.0', 'NAME': 'Total Price of Orders with Quantity > 10 and Price > 100', 'DESCRIPTION': 'Calculate the total price of orders where the quantity is greater than 10 and the price is greater than 100.', 'TABLE': 'Orders_oct_12_2024_20_00', 'BLOCKS': [{'FILTER_BLOCK': {'COLUMNS': ['quantity', 'price'], 'COMPARISON_OPERATOR': '>', 'VALUE': [10, 100]}}, {'SCALAR_BLOCK': {'COLUMNS': ['price'], 'OPERATOR': 'COLUMN_SUM', 'AS': 'total_price'}}]}
# PQL validation errors: ['Invalid value for block at index 0: [10, 100] for VALUE, value can not be a collection']
# PQL validation failed
#  errors: Invalid value for block at index 0: [10, 100] for VALUE, value can not be a collection
# Full agent response: [Message(id='msg_63QtuJOaBj9oswiWI5imtpV0', assistant_id='asst_1Z7wPRRU5nxP7P7BYWyXX25m', attachments=[], completed_at=None, content=[TextContentBlock(text=Text(annotations=[], value='```json\n{\n    "VERSION": "v0.1.0",\n    "NAME": "Total Price of Orders with Quantity > 10 and Price > 100",\n    "DESCRIPTION": "Calculate the total price of orders where the quantity is greater than 10 and the price is greater than 100.",\n    "TABLE": "Orders_oct_12_2024_20_00",\n    "BLOCKS": [\n        {\n            "FILTER_BLOCK": {\n                "COLUMNS": ["quantity"],\n                "COMPARISON_OPERATOR": ">",\n                "VALUE": 10\n            }\n        },\n        {\n            "FILTER_BLOCK": {\n                "COLUMNS": ["price"],\n                "COMPARISON_OPERATOR": ">",\n                "VALUE": 100\n            }\n        },\n        {\n            "SCALAR_BLOCK": {\n                "COLUMNS": ["price"],\n                "OPERATOR": "COLUMN_SUM",\n                "AS": "total_price"\n            }\n        }\n    ]\n}\n```'), type='text')], created_at=1728767324, incomplete_at=None, incomplete_details=None, metadata={}, object='thread.message', role='assistant', run_id='run_3YroiSQA3PTEAdtri0Zaj5fu', status=None, thread_id='thread_aL9r0TkSyabwqBe8dQaLbOfa'), Message(id='msg_D2vl034xKJlohvdH53HzhUC5', assistant_id=None, attachments=[], completed_at=None, content=[TextContentBlock(text=Text(annotations=[], value='PQL validation failed\n errors: Invalid value for block at index 0: [10, 100] for VALUE, value can not be a collection'), type='text')], created_at=1728767323, incomplete_at=None, incomplete_details=None, metadata={}, object='thread.message', role='user', run_id=None, status=None, thread_id='thread_aL9r0TkSyabwqBe8dQaLbOfa'), Message(id='msg_4ZdGdQSQ1wDDd2XdwdkSwQGh', assistant_id='asst_1Z7wPRRU5nxP7P7BYWyXX25m', attachments=[], completed_at=None, content=[TextContentBlock(text=Text(annotations=[], value='```json\n{\n    "VERSION": "v0.1.0",\n    "NAME": "Total Price of Orders with Quantity > 10 and Price > 100",\n    "DESCRIPTION": "Calculate the total price of orders where the quantity is greater than 10 and the price is greater than 100.",\n    "TABLE": "Orders_oct_12_2024_20_00",\n    "BLOCKS": [\n        {\n            "FILTER_BLOCK": {\n                "COLUMNS": ["quantity", "price"],\n                "COMPARISON_OPERATOR": ">",\n                "VALUE": [10, 100]\n            }\n        },\n        {\n            "SCALAR_BLOCK": {\n                "COLUMNS": ["price"],\n                "OPERATOR": "COLUMN_SUM",\n                "AS": "total_price"\n            }\n        }\n    ]\n}\n```'), type='text')], created_at=1728767321, incomplete_at=None, incomplete_details=None, metadata={}, object='thread.message', role='assistant', run_id='run_gD5k7EfTPmtxZE6gXJg9pc4z', status=None, thread_id='thread_aL9r0TkSyabwqBe8dQaLbOfa'), Message(id='msg_o0IW7RMzu6pOmMb11ENYt3RL', assistant_id=None, attachments=[], completed_at=None, content=[TextContentBlock(text=Text(annotations=[], value='Please provide me with a PQL in JSON format that can answer this question, keep it in one JSON and do not add any other text:The following is the table information: Table information:\n\nTable name: Orders_oct_12_2024_20_00\n\nTable description: \n\n\nThe following is the column information in the table: Column information:\nColumn name: order_id\n\n    Column description: \n\n    Column data type: string\n\nColumn name: quantity\n\n    Column description: \n\n    Column data type: float\n\nColumn name: date\n\n    Column description: \n\n    Column data type: date\n\nColumn name: price\n\n    Column description: \n\n    Column data type: float\n\nColumn name: material\n\n    Column description: \n\n    Column data type: string\n\nColumn name: customer\n\n    Column description: \n\n    Column data type: string\n\n\nWhat is the total price of orders with quantity greater than 10 and price greater than 10 ...
# Current agent response to extract: ```json
# {
#     "VERSION": "v0.1.0",
#     "NAME": "Total Price of Orders with Quantity > 10 and Price > 100",
#     "DESCRIPTION": "Calculate the total price of orders where the quantity is greater than 10 and the price is greater than 100.",
#     "TABLE": "Orders_oct_12_2024_20_00",
#     "BLOCKS": [
#         {
#             "FILTER_BLOCK": {
#                 "COLUMNS": ["quantity"],
#                 "COMPARISON_OPERATOR": ">",
#                 "VALUE": 10
#             }
#         },
#         {
#             "FILTER_BLOCK": {
#                 "COLUMNS": ["price"],
#                 "COMPARISON_OPERATOR": ">",
#                 "VALUE": 100
#             }
#         },
#         {
#             "SCALAR_BLOCK": {
#                 "COLUMNS": ["price"],
#                 "OPERATOR": "COLUMN_SUM",
#                 "AS": "total_price"
#             }
#         }
#     ]
# }
# ```
# Extracted JSON: {'VERSION': 'v0.1.0', 'NAME': 'Total Price of Orders with Quantity > 10 and Price > 100', 'DESCRIPTION': 'Calculate the total price of orders where the quantity is greater than 10 and the price is greater than 100.', 'TABLE': 'Orders_oct_12_2024_20_00', 'BLOCKS': [{'FILTER_BLOCK': {'COLUMNS': ['quantity'], 'COMPARISON_OPERATOR': '>', 'VALUE': 10}}, {'FILTER_BLOCK': {'COLUMNS': ['price'], 'COMPARISON_OPERATOR': '>', 'VALUE': 100}}, {'SCALAR_BLOCK': {'COLUMNS': ['price'], 'OPERATOR': 'COLUMN_SUM', 'AS': 'total_price'}}]}
# Validating PQL: {'VERSION': 'v0.1.0', 'NAME': 'Total Price of Orders with Quantity > 10 and Price > 100', 'DESCRIPTION': 'Calculate the total price of orders where the quantity is greater than 10 and the price is greater than 100.', 'TABLE': 'Orders_oct_12_2024_20_00', 'BLOCKS': [{'FILTER_BLOCK': {'COLUMNS': ['quantity'], 'COMPARISON_OPERATOR': '>', 'VALUE': 10}}, {'FILTER_BLOCK': {'COLUMNS': ['price'], 'COMPARISON_OPERATOR': '>', 'VALUE': 100}}, {'SCALAR_BLOCK': {'COLUMNS': ['price'], 'OPERATOR': 'COLUMN_SUM', 'AS': 'total_price'}}]}
# PQL validation errors: []
# PQL: {'VERSION': 'v0.1.0', 'NAME': 'Total Price of Orders with Quantity > 10 and Price > 100', 'DESCRIPTION': 'Calculate the total price of orders where the quantity is greater than 10 and the price is greater than 100.', 'TABLE': 'Orders_oct_12_2024_20_00', 'BLOCKS': [{'FILTER_BLOCK': {'COLUMNS': ['quantity'], 'COMPARISON_OPERATOR': '>', 'VALUE': 10}}, {'FILTER_BLOCK': {'COLUMNS': ['price'], 'COMPARISON_OPERATOR': '>', 'VALUE': 100}}, {'SCALAR_BLOCK': {'COLUMNS': ['price'], 'OPERATOR': 'COLUMN_SUM', 'AS': 'total_price'}}]}
# filter block
# {'FILTER_BLOCK': {'COLUMNS': ['quantity'], 'COMPARISON_OPERATOR': '>', 'VALUE': 10}}
#
#             `latest_table_1b653f20ffb34d9f8655f0f5cfa1953e` AS (
#                 SELECT *
#                 FROM `latest_table_1c1419244cbf484fae8997765b5871ac`
#                 WHERE `quantity` > 10
#             )
#          `quantity` > 10 AND
# filter block
# {'FILTER_BLOCK': {'COLUMNS': ['price'], 'COMPARISON_OPERATOR': '>', 'VALUE': 100}}
#
#             `latest_table_58fe4db8fdc143159c794cf365ed7d39` AS (
#                 SELECT *
#                 FROM `latest_table_1b653f20ffb34d9f8655f0f5cfa1953e`
#                 WHERE `price` > 100
#             )
#          `price` > 100 AND
# WITH
# `latest_table_1c1419244cbf484fae8997765b5871ac` AS (
# SELECT * FROM `Orders_oct_12_2024_20_00`
# ),
#
#             `latest_table_1b653f20ffb34d9f8655f0f5cfa1953e` AS (
#                 SELECT *
#                 FROM `latest_table_1c1419244cbf484fae8997765b5871ac`
#                 WHERE `quantity` > 10
#             )
#         ,
#             `latest_table_58fe4db8fdc143159c794cf365ed7d39` AS (
#                 SELECT *
#                 FROM `latest_table_1b653f20ffb34d9f8655f0f5cfa1953e`
#                 WHERE `price` > 100
#             )
#
#             SELECT SUM(`price`) AS `total_price`
#             FROM `latest_table_58fe4db8fdc143159c794cf365ed7d39`;
#
# Full agent response: [Message(id='msg_dlUUCT1EF5FtjDpmlacLUADi', assistant_id='asst_1Z7wPRRU5nxP7P7BYWyXX25m', attachments=[], completed_at=None, content=[TextContentBlock(text=Text(annotations=[], value='```json\n{\n    "VERSION": "v0.1.0",\n    "NAME": "Total Price of Orders",\n    "DESCRIPTION": "The total price of orders with quantity greater than 10, price greater than 100, and order date after 2020-01-01.",\n    "TABLE": "Orders_oct_12_2024_20_00",\n    "BLOCKS": [\n        {\n            "FILTER_BLOCK": {\n                "COLUMNS": ["quantity", "price", "date"],\n                "COMPARISON_OPERATOR": ">",\n                "VALUE": [10, 100, "2020-01-01"]\n            }\n        },\n        {\n            "SCALAR_BLOCK": {\n                "COLUMNS": ["price"],\n                "OPERATOR": "COLUMN_SUM",\n                "AS": "total_price"\n            }\n        }\n    ]\n}\n```'), type='text')], created_at=1728767332, incomplete_at=None, incomplete_details=None, metadata={}, object='thread.message', role='assistant', run_id='run_6GBSo3V2hwNkPj5TpLLSuqJf', status=None, thread_id='thread_E9EDzW920mHb0RqkoZ0riMCA'), Message(id='msg_UxMrRyrdOm9FdRhnLUGcPvA8', assistant_id=None, attachments=[], completed_at=None, content=[TextContentBlock(text=Text(annotations=[], value='Please provide me with a PQL in JSON format that can answer this question, keep it in one JSON and do not add any other text:The following is the table information: Table information:\n\nTable name: Orders_oct_12_2024_20_00\n\nTable description: \n\n\nThe following is the column information in the table: Column information:\nColumn name: order_id\n\n    Column description: \n\n    Column data type: string\n\nColumn name: quantity\n\n    Column description: \n\n    Column data type: float\n\nColumn name: date\n\n    Column description: \n\n    Column data type: date\n\nColumn name: price\n\n    Column description: \n\n    Column data type: float\n\nColumn name: material\n\n    Column description: \n\n    Column data type: string\n\nColumn name: customer\n\n    Column description: \n\n    Column data type: string\n\n\nWhat is the total price of orders with quantity greater than 10 and price greater than 100 and order date greater than 2020-01-01?'), type='text')], created_at=1728767327, incomplete_at=None, incomplete_details=None, metadata={}, object='thread.message', role='user', run_id=None, status=None, thread_id='thread_E9EDzW920mHb0RqkoZ0riMCA')]
# Current agent response to extract: ```json
# {
#     "VERSION": "v0.1.0",
#     "NAME": "Total Price of Orders",
#     "DESCRIPTION": "The total price of orders with quantity greater than 10, price greater than 100, and order date after 2020-01-01.",
#     "TABLE": "Orders_oct_12_2024_20_00",
#     "BLOCKS": [
#         {
#             "FILTER_BLOCK": {
#                 "COLUMNS": ["quantity", "price", "date"],
#                 "COMPARISON_OPERATOR": ">",
#                 "VALUE": [10, 100, "2020-01-01"]
#             }
#         },
#         {
#             "SCALAR_BLOCK": {
#                 "COLUMNS": ["price"],
#                 "OPERATOR": "COLUMN_SUM",
#                 "AS": "total_price"
#             }
#         }
#     ]
# }
# ```
# Extracted JSON: {'VERSION': 'v0.1.0', 'NAME': 'Total Price of Orders', 'DESCRIPTION': 'The total price of orders with quantity greater than 10, price greater than 100, and order date after 2020-01-01.', 'TABLE': 'Orders_oct_12_2024_20_00', 'BLOCKS': [{'FILTER_BLOCK': {'COLUMNS': ['quantity', 'price', 'date'], 'COMPARISON_OPERATOR': '>', 'VALUE': [10, 100, '2020-01-01']}}, {'SCALAR_BLOCK': {'COLUMNS': ['price'], 'OPERATOR': 'COLUMN_SUM', 'AS': 'total_price'}}]}
# Validating PQL: {'VERSION': 'v0.1.0', 'NAME': 'Total Price of Orders', 'DESCRIPTION': 'The total price of orders with quantity greater than 10, price greater than 100, and order date after 2020-01-01.', 'TABLE': 'Orders_oct_12_2024_20_00', 'BLOCKS': [{'FILTER_BLOCK': {'COLUMNS': ['quantity', 'price', 'date'], 'COMPARISON_OPERATOR': '>', 'VALUE': [10, 100, '2020-01-01']}}, {'SCALAR_BLOCK': {'COLUMNS': ['price'], 'OPERATOR': 'COLUMN_SUM', 'AS': 'total_price'}}]}
# PQL validation errors: ["Invalid value for block at index 0: [10, 100, '2020-01-01'] for VALUE, value can not be a collection"]
# PQL validation failed
#  errors: Invalid value for block at index 0: [10, 100, '2020-01-01'] for VALUE, value can not be a collection
# Full agent response: [Message(id='msg_DyyDC9flxRAQXTTbwKsbzLE6', assistant_id='asst_1Z7wPRRU5nxP7P7BYWyXX25m', attachments=[], completed_at=None, content=[TextContentBlock(text=Text(annotations=[], value='```json\n{\n    "VERSION": "v0.1.0",\n    "NAME": "Total Price of Orders",\n    "DESCRIPTION": "The total price of orders with quantity greater than 10, price greater than 100, and order date after 2020-01-01.",\n    "TABLE": "Orders_oct_12_2024_20_00",\n    "BLOCKS": [\n        {\n            "FILTER_BLOCK": {\n                "AND": [\n                    {\n                        "COLUMN": "quantity",\n                        "COMPARISON_OPERATOR": ">",\n                        "VALUE": 10\n                    },\n                    {\n                        "COLUMN": "price",\n                        "COMPARISON_OPERATOR": ">",\n                        "VALUE": 100\n                    },\n                    {\n                        "COLUMN": "date",\n                        "COMPARISON_OPERATOR": ">",\n                        "VALUE": "2020-01-01"\n                    }\n                ]\n            }\n        },\n        {\n            "SCALAR_BLOCK": {\n                "COLUMN": "price",\n                "OPERATOR": "COLUMN_SUM",\n                "AS": "total_price"\n            }\n        }\n    ]\n}\n```'), type='text')], created_at=1728767336, incomplete_at=None, incomplete_details=None, metadata={}, object='thread.message', role='assistant', run_id='run_lOTp83xDyMKqB4rzYmENguim', status=None, thread_id='thread_E9EDzW920mHb0RqkoZ0riMCA'), Message(id='msg_OJErnO8HtJZPqawl0dBET90M', assistant_id=None, attachments=[], completed_at=None, content=[TextContentBlock(text=Text(annotations=[], value="PQL validation failed\n errors: Invalid value for block at index 0: [10, 100, '2020-01-01'] for VALUE, value can not be a collection"), type='text')], created_at=1728767334, incomplete_at=None, incomplete_details=None, metadata={}, object='thread.message', role='user', run_id=None, status=None, thread_id='thread_E9EDzW920mHb0RqkoZ0riMCA'), Message(id='msg_dlUUCT1EF5FtjDpmlacLUADi', assistant_id='asst_1Z7wPRRU5nxP7P7BYWyXX25m', attachments=[], completed_at=None, content=[TextContentBlock(text=Text(annotations=[], value='```json\n{\n    "VERSION": "v0.1.0",\n    "NAME": "Total Price of Orders",\n    "DESCRIPTION": "The total price of orders with quantity greater than 10, price greater than 100, and order date after 2020-01-01.",\n    "TABLE": "Orders_oct_12_2024_20_00",\n    "BLOCKS": [\n        {\n            "FILTER_BLOCK": {\n                "COLUMNS": ["quantity", "price", "date"],\n                "COMPARISON_OPERATOR": ">",\n                "VALUE": [10, 100, "2020-01-01"]\n            }\n        },\n        {\n            "SCALAR_BLOCK": {\n                "COLUMNS": ["price"],\n                "OPERATOR": "COLUMN_SUM",\n                "AS": "total_price"\n            }\n        }\n    ]\n}\n```'), type='text')], created_at=1728767332, incomplete_at=None, incomplete_details=None, metadata={}, object='thread.message', role='assistant', run_id='run_6GBSo3V2hwNkPj5TpLLSuqJf', status=None, thread_id='thread_E9EDzW920mHb0RqkoZ0riMCA'), Message(id='msg_UxMrRyrdOm9FdRhnLUGcPvA8', assistant_id=None, attachments=[], completed_at=None, content=[TextContentBlock(text=Text(annotations=[], value='Please provide me with a PQL in JSON format that can answer this question, keep it in one JSON and do not add any other text:The following is the table information: Table information:\n\nTable name: Orders_oct_12_2024_20_00\n\nTable description: \n\n\nThe following is the column information in the table: Column information:\nColumn name: order_id\n\n    Column description: \n\n    Column data type: string\n\nColumn name: quantity\n\n    Column description: \n\n    Column data type: float\n\nColumn name: date\n\n    Column description: \n\n    Column data type: date\n\nColumn name: price\n\n    Column description: \n\n    Column data ty ...
# Current agent response to extract: ```json
# {
#     "VERSION": "v0.1.0",
#     "NAME": "Total Price of Orders",
#     "DESCRIPTION": "The total price of orders with quantity greater than 10, price greater than 100, and order date after 2020-01-01.",
#     "TABLE": "Orders_oct_12_2024_20_00",
#     "BLOCKS": [
#         {
#             "FILTER_BLOCK": {
#                 "AND": [
#                     {
#                         "COLUMN": "quantity",
#                         "COMPARISON_OPERATOR": ">",
#                         "VALUE": 10
#                     },
#                     {
#                         "COLUMN": "price",
#                         "COMPARISON_OPERATOR": ">",
#                         "VALUE": 100
#                     },
#                     {
#                         "COLUMN": "date",
#                         "COMPARISON_OPERATOR": ">",
#                         "VALUE": "2020-01-01"
#                     }
#                 ]
#             }
#         },
#         {
#             "SCALAR_BLOCK": {
#                 "COLUMN": "price",
#                 "OPERATOR": "COLUMN_SUM",
#                 "AS": "total_price"
#             }
#         }
#     ]
# }
# ```
# Extracted JSON: {'VERSION': 'v0.1.0', 'NAME': 'Total Price of Orders', 'DESCRIPTION': 'The total price of orders with quantity greater than 10, price greater than 100, and order date after 2020-01-01.', 'TABLE': 'Orders_oct_12_2024_20_00', 'BLOCKS': [{'FILTER_BLOCK': {'AND': [{'COLUMN': 'quantity', 'COMPARISON_OPERATOR': '>', 'VALUE': 10}, {'COLUMN': 'price', 'COMPARISON_OPERATOR': '>', 'VALUE': 100}, {'COLUMN': 'date', 'COMPARISON_OPERATOR': '>', 'VALUE': '2020-01-01'}]}}, {'SCALAR_BLOCK': {'COLUMN': 'price', 'OPERATOR': 'COLUMN_SUM', 'AS': 'total_price'}}]}
# Validating PQL: {'VERSION': 'v0.1.0', 'NAME': 'Total Price of Orders', 'DESCRIPTION': 'The total price of orders with quantity greater than 10, price greater than 100, and order date after 2020-01-01.', 'TABLE': 'Orders_oct_12_2024_20_00', 'BLOCKS': [{'FILTER_BLOCK': {'AND': [{'COLUMN': 'quantity', 'COMPARISON_OPERATOR': '>', 'VALUE': 10}, {'COLUMN': 'price', 'COMPARISON_OPERATOR': '>', 'VALUE': 100}, {'COLUMN': 'date', 'COMPARISON_OPERATOR': '>', 'VALUE': '2020-01-01'}]}}, {'SCALAR_BLOCK': {'COLUMN': 'price', 'OPERATOR': 'COLUMN_SUM', 'AS': 'total_price'}}]}
# PQL validation errors: ["Invalid key: AND at BLOCKS[0].FILTER_BLOCK.AND, valid keys are: ['TABLE', 'BLOCKS', 'EXTENSION_BLOCKS', 'COLUMNS', 'OPERATOR', 'AS', 'GROUP_BY', 'GROUPING_OPERATORS', 'GROUPING_BLOCK', 'FILTER_BLOCK', 'COMPARISON_OPERATOR', 'VALUE', 'SCALAR_BLOCK', 'VERSION', 'DESCRIPTION', 'NAME']", "Invalid key: COLUMN at BLOCKS[0].FILTER_BLOCK.AND[0].COLUMN, valid keys are: ['TABLE', 'BLOCKS', 'EXTENSION_BLOCKS', 'COLUMNS', 'OPERATOR', 'AS', 'GROUP_BY', 'GROUPING_OPERATORS', 'GROUPING_BLOCK', 'FILTER_BLOCK', 'COMPARISON_OPERATOR', 'VALUE', 'SCALAR_BLOCK', 'VERSION', 'DESCRIPTION', 'NAME']", "Invalid key: COLUMN at BLOCKS[0].FILTER_BLOCK.AND[1].COLUMN, valid keys are: ['TABLE', 'BLOCKS', 'EXTENSION_BLOCKS', 'COLUMNS', 'OPERATOR', 'AS', 'GROUP_BY', 'GROUPING_OPERATORS', 'GROUPING_BLOCK', 'FILTER_BLOCK', 'COMPARISON_OPERATOR', 'VALUE', 'SCALAR_BLOCK', 'VERSION', 'DESCRIPTION', 'NAME']", "Invalid key: COLUMN at BLOCKS[0].FILTER_BLOCK.AND[2].COLUMN, valid keys are: ['TABLE', 'BLOCKS', 'EXTENSION_BLOCKS', 'COLUMNS', 'OPERATOR', 'AS', 'GROUP_BY', 'GROUPING_OPERATORS', 'GROUPING_BLOCK', 'FILTER_BLOCK', 'COMPARISON_OPERATOR', 'VALUE', 'SCALAR_BLOCK', 'VERSION', 'DESCRIPTION', 'NAME']", "Invalid key: COLUMN at BLOCKS[1].SCALAR_BLOCK.COLUMN, valid keys are: ['TABLE', 'BLOCKS', 'EXTENSION_BLOCKS', 'COLUMNS', 'OPERATOR', 'AS', 'GROUP_BY', 'GROUPING_OPERATORS', 'GROUPING_BLOCK', 'FILTER_BLOCK', 'COMPARISON_OPERATOR', 'VALUE', 'SCALAR_BLOCK', 'VERSION', 'DESCRIPTION', 'NAME']", "Missing key for block at index 0: COLUMNS, required keys are: ['COLUMNS', 'COMPARISON_OPERATOR', 'VALUE']", "Missing key for block at index 0: COMPARISON_OPERATOR, required keys are: ['COLUMNS', 'COMPARISON_OPERATOR', 'VALUE']", "Missing key for block at index 0: VALUE, required keys are: ['COLUMNS', 'COMPARISON_OPERATOR', 'VALUE']", "Invalid key for block at index 0: AND, valid keys are: ['COLUMNS', 'COMPARISON_OPERATOR', 'VALUE']", 'Invalid key for block at index 0: AND', "Missing key for block at index 1: COLUMNS, required keys are: ['COLUMNS', 'OPERATOR', 'AS']", "Invalid key for block at index 1: COLUMN, valid keys are: ['COLUMNS', 'OPERATOR', 'AS']", 'Invalid key for block at index 1: COLUMN']
# PQL validation failed
#  errors: Invalid key: AND at BLOCKS[0].FILTER_BLOCK.AND, valid keys are: ['TABLE', 'BLOCKS', 'EXTENSION_BLOCKS', 'COLUMNS', 'OPERATOR', 'AS', 'GROUP_BY', 'GROUPING_OPERATORS', 'GROUPING_BLOCK', 'FILTER_BLOCK', 'COMPARISON_OPERATOR', 'VALUE', 'SCALAR_BLOCK', 'VERSION', 'DESCRIPTION', 'NAME']
# Invalid key: COLUMN at BLOCKS[0].FILTER_BLOCK.AND[0].COLUMN, valid keys are: ['TABLE', 'BLOCKS', 'EXTENSION_BLOCKS', 'COLUMNS', 'OPERATOR', 'AS', 'GROUP_BY', 'GROUPING_OPERATORS', 'GROUPING_BLOCK', 'FILTER_BLOCK', 'COMPARISON_OPERATOR', 'VALUE', 'SCALAR_BLOCK', 'VERSION', 'DESCRIPTION', 'NAME']
# Invalid key: COLUMN at BLOCKS[0].FILTER_BLOCK.AND[1].COLUMN, valid keys are: ['TABLE', 'BLOCKS', 'EXTENSION_BLOCKS', 'COLUMNS', 'OPERATOR', 'AS', 'GROUP_BY', 'GROUPING_OPERATORS', 'GROUPING_BLOCK', 'FILTER_BLOCK', 'COMPARISON_OPERATOR', 'VALUE', 'SCALAR_BLOCK', 'VERSION', 'DESCRIPTION', 'NAME']
# Invalid key: COLUMN at BLOCKS[0].FILTER_BLOCK.AND[2].COLUMN, valid keys are: ['TABLE', 'BLOCKS', 'EXTENSION_BLOCKS', 'COLUMNS', 'OPERATOR', 'AS', 'GROUP_BY', 'GROUPING_OPERATORS', 'GROUPING_BLOCK', 'FILTER_BLOCK', 'COMPARISON_OPERATOR', 'VALUE', 'SCALAR_BLOCK', 'VERSION', 'DESCRIPTION', 'NAME']
# Invalid key: COLUMN at BLOCKS[1].SCALAR_BLOCK.COLUMN, valid keys are: ['TABLE', 'BLOCKS', 'EXTENSION_BLOCKS', 'COLUMNS', 'OPERATOR', 'AS', 'GROUP_BY', 'GROUPING_OPERATORS', 'GROUPING_BLOCK', 'FILTER_BLOCK', 'COMPARISON_OPERATOR', 'VALUE', 'SCALAR_BLOCK', 'VERSION', 'DESCRIPTION', 'NAME']
# Missing key for block at index 0: COLUMNS, required keys are: ['COLUMNS', 'COMPARISON_OPERATOR', 'VALUE']
# Missing key for block at index 0: COMPARISON_OPERATOR, required keys are: ['COLUMNS', 'COMPARISON_OPERATOR', 'VALUE']
# Missing key for block at index 0: VALUE, required keys are: ['COLUMNS', 'COMPARISON_OPERATOR', 'VALUE']
# Invalid key for block at index 0: AND, valid keys are: ['COLUMNS', 'COMPARISON_OPERATOR', 'VALUE']
# Invalid key for block at index 0: AND
# Missing key for block at index 1: COLUMNS, required keys are: ['COLUMNS', 'OPERATOR', 'AS']
# Invalid key for block at index 1: COLUMN, valid keys are: ['COLUMNS', 'OPERATOR', 'AS']
# Invalid key for block at index 1: COLUMN
# Full agent response: [Message(id='msg_wuPKNjtZcnJEeWZHm8M1Znlh', assistant_id='asst_1Z7wPRRU5nxP7P7BYWyXX25m', attachments=[], completed_at=None, content=[TextContentBlock(text=Text(annotations=[], value='```json\n{\n    "VERSION": "v0.1.0",\n    "NAME": "Total Price of Orders",\n    "DESCRIPTION": "The total price of orders with quantity greater than 10, price greater than 100, and order date after 2020-01-01.",\n    "TABLE": "Orders_oct_12_2024_20_00",\n    "BLOCKS": [\n        {\n            "FILTER_BLOCK": {\n                "COLUMNS": ["quantity"],\n                "COMPARISON_OPERATOR": ">",\n                "VALUE": 10\n            }\n        },\n        {\n            "FILTER_BLOCK": {\n                "COLUMNS": ["price"],\n                "COMPARISON_OPERATOR": ">",\n                "VALUE": 100\n            }\n        },\n        {\n            "FILTER_BLOCK": {\n                "COLUMNS": ["date"],\n                "COMPARISON_OPERATOR": ">",\n                "VALUE": "2020-01-01"\n            }\n        },\n        {\n            "SCALAR_BLOCK": {\n                "COLUMNS": ["price"],\n                "OPERATOR": "COLUMN_SUM",\n                "AS": "total_price"\n            }\n        }\n    ]\n}\n```'), type='text')], created_at=1728767340, incomplete_at=None, incomplete_details=None, metadata={}, object='thread.message', role='assistant', run_id='run_Kvt4wXz2NlOnLKhDWitJCiFj', status=None, thread_id='thread_E9EDzW920mHb0RqkoZ0riMCA'), Message(id='msg_LKupEmkoiyZEA6C0BMBUXujd', assistant_id=None, attachments=[], completed_at=None, content=[TextContentBlock(text=Text(annotations=[], value="PQL validation failed\n errors: Invalid key: AND at BLOCKS[0].FILTER_BLOCK.AND, valid keys are: ['TABLE', 'BLOCKS', 'EXTENSION_BLOCKS', 'COLUMNS', 'OPERATOR', 'AS', 'GROUP_BY', 'GROUPING_OPERATORS', 'GROUPING_BLOCK', 'FILTER_BLOCK', 'COMPARISON_OPERATOR', 'VALUE', 'SCALAR_BLOCK', 'VERSION', 'DESCRIPTION', 'NAME']\nInvalid key: COLUMN at BLOCKS[0].FILTER_BLOCK.AND[0].COLUMN, valid keys are: ['TABLE', 'BLOCKS', 'EXTENSION_BLOCKS', 'COLUMNS', 'OPERATOR', 'AS', 'GROUP_BY', 'GROUPING_OPERATORS', 'GROUPING_BLOCK', 'FILTER_BLOCK', 'COMPARISON_OPERATOR', 'VALUE', 'SCALAR_BLOCK', 'VERSION', 'DESCRIPTION', 'NAME']\nInvalid key: COLUMN at BLOCKS[0].FILTER_BLOCK.AND[1].COLUMN, valid keys are: ['TABLE', 'BLOCKS', 'EXTENSION_BLOCKS', 'COLUMNS', 'OPERATOR', 'AS', 'GROUP_BY', 'GROUPING_OPERATORS', 'GROUPING_BLOCK', 'FILTER_BLOCK', 'COMPARISON_OPERATOR', 'VALUE', 'SCALAR_BLOCK', 'VERSION', 'DESCRIPTION', 'NAME']\nInvalid key: COLUMN at BLOCKS[0].FILTER_BLOCK.AND[2].COLUMN, valid keys are: ['TABLE', 'BLOCKS', 'EXTENSION_BLOCKS', 'COLUMNS', 'OPERATOR', 'AS', 'GROUP_BY', 'GROUPING_OPERATORS', 'GROUPING_BLOCK', 'FILTER_BLOCK', 'COMPARISON_OPERATOR', 'VALUE', 'SCALAR_BLOCK', 'VERSION', 'DESCRIPTION', 'NAME']\nInvalid key: COLUMN at BLOCKS[1].SCALAR_BLOCK.COLUMN, valid keys are: ['TABLE', 'BLOCKS', 'EXTENSION_BLOCKS', 'COLUMNS', 'OPERATOR', 'AS', 'GROUP_BY', 'GROUPING_OPERATORS', 'GROUPING_BLOCK', 'FILTER_BLOCK', 'COMPARISON_OPERATOR', 'VALUE', 'SCALAR_BLOCK', 'VERSION', 'DESCRIPTION', 'NAME']\nMissing key for block at index 0: COLUMNS, required keys are: ['COLUMNS', 'COMPARISON_OPERATOR', 'VALUE']\nMissing key for block at index 0: COMPARISON_OPERATOR, required keys are: ['COLUMNS', 'COMPARISON_OPERATOR', 'VALUE']\nMissing key for block at index 0: VALUE, required keys are: ['COLUMNS', 'COMPARISON_OPERATOR', 'VALUE']\nInvalid key for block at index 0: AND, valid keys are: ['COLUMNS', 'COMPARISON_OPERATOR', 'VALUE']\nInvalid key for block at index 0: AND\nMissing key for block at index 1: COLUMNS, required keys are: ['COLUMNS', 'OPERATOR', 'AS']\nInvalid key for block at index 1: COLUMN, valid keys are: ['COLUMNS', 'OPERATOR', 'AS']\nInvalid key for block at index 1: COLUMN"), type='text')], created_at=1728767339, incomplete_at=None, incomplete_details=None, metadata={}, object='thread.message', role='user', run_id=None, status=None, thread_id='thr ...
# Current agent response to extract: ```json
# {
#     "VERSION": "v0.1.0",
#     "NAME": "Total Price of Orders",
#     "DESCRIPTION": "The total price of orders with quantity greater than 10, price greater than 100, and order date after 2020-01-01.",
#     "TABLE": "Orders_oct_12_2024_20_00",
#     "BLOCKS": [
#         {
#             "FILTER_BLOCK": {
#                 "COLUMNS": ["quantity"],
#                 "COMPARISON_OPERATOR": ">",
#                 "VALUE": 10
#             }
#         },
#         {
#             "FILTER_BLOCK": {
#                 "COLUMNS": ["price"],
#                 "COMPARISON_OPERATOR": ">",
#                 "VALUE": 100
#             }
#         },
#         {
#             "FILTER_BLOCK": {
#                 "COLUMNS": ["date"],
#                 "COMPARISON_OPERATOR": ">",
#                 "VALUE": "2020-01-01"
#             }
#         },
#         {
#             "SCALAR_BLOCK": {
#                 "COLUMNS": ["price"],
#                 "OPERATOR": "COLUMN_SUM",
#                 "AS": "total_price"
#             }
#         }
#     ]
# }
# ```
# Extracted JSON: {'VERSION': 'v0.1.0', 'NAME': 'Total Price of Orders', 'DESCRIPTION': 'The total price of orders with quantity greater than 10, price greater than 100, and order date after 2020-01-01.', 'TABLE': 'Orders_oct_12_2024_20_00', 'BLOCKS': [{'FILTER_BLOCK': {'COLUMNS': ['quantity'], 'COMPARISON_OPERATOR': '>', 'VALUE': 10}}, {'FILTER_BLOCK': {'COLUMNS': ['price'], 'COMPARISON_OPERATOR': '>', 'VALUE': 100}}, {'FILTER_BLOCK': {'COLUMNS': ['date'], 'COMPARISON_OPERATOR': '>', 'VALUE': '2020-01-01'}}, {'SCALAR_BLOCK': {'COLUMNS': ['price'], 'OPERATOR': 'COLUMN_SUM', 'AS': 'total_price'}}]}
# Validating PQL: {'VERSION': 'v0.1.0', 'NAME': 'Total Price of Orders', 'DESCRIPTION': 'The total price of orders with quantity greater than 10, price greater than 100, and order date after 2020-01-01.', 'TABLE': 'Orders_oct_12_2024_20_00', 'BLOCKS': [{'FILTER_BLOCK': {'COLUMNS': ['quantity'], 'COMPARISON_OPERATOR': '>', 'VALUE': 10}}, {'FILTER_BLOCK': {'COLUMNS': ['price'], 'COMPARISON_OPERATOR': '>', 'VALUE': 100}}, {'FILTER_BLOCK': {'COLUMNS': ['date'], 'COMPARISON_OPERATOR': '>', 'VALUE': '2020-01-01'}}, {'SCALAR_BLOCK': {'COLUMNS': ['price'], 'OPERATOR': 'COLUMN_SUM', 'AS': 'total_price'}}]}
# PQL validation errors: []
# PQL: {'VERSION': 'v0.1.0', 'NAME': 'Total Price of Orders', 'DESCRIPTION': 'The total price of orders with quantity greater than 10, price greater than 100, and order date after 2020-01-01.', 'TABLE': 'Orders_oct_12_2024_20_00', 'BLOCKS': [{'FILTER_BLOCK': {'COLUMNS': ['quantity'], 'COMPARISON_OPERATOR': '>', 'VALUE': 10}}, {'FILTER_BLOCK': {'COLUMNS': ['price'], 'COMPARISON_OPERATOR': '>', 'VALUE': 100}}, {'FILTER_BLOCK': {'COLUMNS': ['date'], 'COMPARISON_OPERATOR': '>', 'VALUE': '2020-01-01'}}, {'SCALAR_BLOCK': {'COLUMNS': ['price'], 'OPERATOR': 'COLUMN_SUM', 'AS': 'total_price'}}]}
# filter block
# {'FILTER_BLOCK': {'COLUMNS': ['quantity'], 'COMPARISON_OPERATOR': '>', 'VALUE': 10}}
#
#             `latest_table_bde7af1e7cd54c5f86d3e1c2e92e9361` AS (
#                 SELECT *
#                 FROM `latest_table_071cac5ad2b24d87a397e2fdfedbccb0`
#                 WHERE `quantity` > 10
#             )
#          `quantity` > 10 AND
# filter block
# {'FILTER_BLOCK': {'COLUMNS': ['price'], 'COMPARISON_OPERATOR': '>', 'VALUE': 100}}
#
#             `latest_table_148ad5bd26c3482993b4a9c13285e3a9` AS (
#                 SELECT *
#                 FROM `latest_table_bde7af1e7cd54c5f86d3e1c2e92e9361`
#                 WHERE `price` > 100
#             )
#          `price` > 100 AND
# filter block
# {'FILTER_BLOCK': {'COLUMNS': ['date'], 'COMPARISON_OPERATOR': '>', 'VALUE': '2020-01-01'}}
#
#             `latest_table_8eab3ba335f24c1d8024688704feeadb` AS (
#                 SELECT *
#                 FROM `latest_table_148ad5bd26c3482993b4a9c13285e3a9`
#                 WHERE `date` > '2020-01-01'
#             )
#          `date` > '2020-01-01' AND
# WITH
# `latest_table_071cac5ad2b24d87a397e2fdfedbccb0` AS (
# SELECT * FROM `Orders_oct_12_2024_20_00`
# ),
#
#             `latest_table_bde7af1e7cd54c5f86d3e1c2e92e9361` AS (
#                 SELECT *
#                 FROM `latest_table_071cac5ad2b24d87a397e2fdfedbccb0`
#                 WHERE `quantity` > 10
#             )
#         ,
#             `latest_table_148ad5bd26c3482993b4a9c13285e3a9` AS (
#                 SELECT *
#                 FROM `latest_table_bde7af1e7cd54c5f86d3e1c2e92e9361`
#                 WHERE `price` > 100
#             )
#         ,
#             `latest_table_8eab3ba335f24c1d8024688704feeadb` AS (
#                 SELECT *
#                 FROM `latest_table_148ad5bd26c3482993b4a9c13285e3a9`
#                 WHERE `date` > '2020-01-01'
#             )
#
#             SELECT SUM(`price`) AS `total_price`
#             FROM `latest_table_8eab3ba335f24c1d8024688704feeadb`;
#
# Full agent response: [Message(id='msg_fKB12ae66jncAvIJd499FZUR', assistant_id='asst_1Z7wPRRU5nxP7P7BYWyXX25m', attachments=[], completed_at=None, content=[TextContentBlock(text=Text(annotations=[], value='```json\n{\n    "VERSION": "v0.1.0",\n    "NAME": "Total Price of Specific Orders",\n    "DESCRIPTION": "Calculate the total price of orders with quantity greater than 10, price greater than 100, and order date between 2020-01-01 and 2021-01-01.",\n    "TABLE": "Orders_oct_12_2024_20_00",\n    "BLOCKS": [\n        {\n            "FILTER_BLOCK": {\n                "COLUMNS": ["quantity"],\n                "COMPARISON_OPERATOR": ">",\n                "VALUE": 10\n            }\n        },\n        {\n            "FILTER_BLOCK": {\n                "COLUMNS": ["price"],\n                "COMPARISON_OPERATOR": ">",\n                "VALUE": 100\n            }\n        },\n        {\n            "FILTER_BLOCK": {\n                "COLUMNS": ["date"],\n                "COMPARISON_OPERATOR": ">",\n                "VALUE": "2020-01-01"\n            }\n        },\n        {\n            "FILTER_BLOCK": {\n                "COLUMNS": ["date"],\n                "COMPARISON_OPERATOR": "<",\n                "VALUE": "2021-01-01"\n            }\n        },\n        {\n            "SCALAR_BLOCK": {\n                "COLUMNS": ["price"],\n                "OPERATOR": "COLUMN_SUM",\n                "AS": "total_price"\n            }\n        }\n    ]\n}\n```'), type='text')], created_at=1728767348, incomplete_at=None, incomplete_details=None, metadata={}, object='thread.message', role='assistant', run_id='run_GXla5yAIliYFdG5DXQmT2QAJ', status=None, thread_id='thread_nQ3YHujFsediIByjPHHlwkS0'), Message(id='msg_gZqP5131poXFkHwQfNaAJ5Os', assistant_id=None, attachments=[], completed_at=None, content=[TextContentBlock(text=Text(annotations=[], value='Please provide me with a PQL in JSON format that can answer this question, keep it in one JSON and do not add any other text:The following is the table information: Table information:\n\nTable name: Orders_oct_12_2024_20_00\n\nTable description: \n\n\nThe following is the column information in the table: Column information:\nColumn name: order_id\n\n    Column description: \n\n    Column data type: string\n\nColumn name: quantity\n\n    Column description: \n\n    Column data type: float\n\nColumn name: date\n\n    Column description: \n\n    Column data type: date\n\nColumn name: price\n\n    Column description: \n\n    Column data type: float\n\nColumn name: material\n\n    Column description: \n\n    Column data type: string\n\nColumn name: customer\n\n    Column description: \n\n    Column data type: string\n\n\nWhat is the total price of orders with quantity greater than 10 and price greater than 100 and order date greater than 2020-01-01 and order date less than 2021-01-01?'), type='text')], created_at=1728767345, incomplete_at=None, incomplete_details=None, metadata={}, object='thread.message', role='user', run_id=None, status=None, thread_id='thread_nQ3YHujFsediIByjPHHlwkS0')]
# Current agent response to extract: ```json
# {
#     "VERSION": "v0.1.0",
#     "NAME": "Total Price of Specific Orders",
#     "DESCRIPTION": "Calculate the total price of orders with quantity greater than 10, price greater than 100, and order date between 2020-01-01 and 2021-01-01.",
#     "TABLE": "Orders_oct_12_2024_20_00",
#     "BLOCKS": [
#         {
#             "FILTER_BLOCK": {
#                 "COLUMNS": ["quantity"],
#                 "COMPARISON_OPERATOR": ">",
#                 "VALUE": 10
#             }
#         },
#         {
#             "FILTER_BLOCK": {
#                 "COLUMNS": ["price"],
#                 "COMPARISON_OPERATOR": ">",
#                 "VALUE": 100
#             }
#         },
#         {
#             "FILTER_BLOCK": {
#                 "COLUMNS": ["date"],
#                 "COMPARISON_OPERATOR": ">",
#                 "VALUE": "2020-01-01"
#             }
#         },
#         {
#             "FILTER_BLOCK": {
#                 "COLUMNS": ["date"],
#                 "COMPARISON_OPERATOR": "<",
#                 "VALUE": "2021-01-01"
#             }
#         },
#         {
#             "SCALAR_BLOCK": {
#                 "COLUMNS": ["price"],
#                 "OPERATOR": "COLUMN_SUM",
#                 "AS": "total_price"
#             }
#         }
#     ]
# }
# ```
# Extracted JSON: {'VERSION': 'v0.1.0', 'NAME': 'Total Price of Specific Orders', 'DESCRIPTION': 'Calculate the total price of orders with quantity greater than 10, price greater than 100, and order date between 2020-01-01 and 2021-01-01.', 'TABLE': 'Orders_oct_12_2024_20_00', 'BLOCKS': [{'FILTER_BLOCK': {'COLUMNS': ['quantity'], 'COMPARISON_OPERATOR': '>', 'VALUE': 10}}, {'FILTER_BLOCK': {'COLUMNS': ['price'], 'COMPARISON_OPERATOR': '>', 'VALUE': 100}}, {'FILTER_BLOCK': {'COLUMNS': ['date'], 'COMPARISON_OPERATOR': '>', 'VALUE': '2020-01-01'}}, {'FILTER_BLOCK': {'COLUMNS': ['date'], 'COMPARISON_OPERATOR': '<', 'VALUE': '2021-01-01'}}, {'SCALAR_BLOCK': {'COLUMNS': ['price'], 'OPERATOR': 'COLUMN_SUM', 'AS': 'total_price'}}]}
# Validating PQL: {'VERSION': 'v0.1.0', 'NAME': 'Total Price of Specific Orders', 'DESCRIPTION': 'Calculate the total price of orders with quantity greater than 10, price greater than 100, and order date between 2020-01-01 and 2021-01-01.', 'TABLE': 'Orders_oct_12_2024_20_00', 'BLOCKS': [{'FILTER_BLOCK': {'COLUMNS': ['quantity'], 'COMPARISON_OPERATOR': '>', 'VALUE': 10}}, {'FILTER_BLOCK': {'COLUMNS': ['price'], 'COMPARISON_OPERATOR': '>', 'VALUE': 100}}, {'FILTER_BLOCK': {'COLUMNS': ['date'], 'COMPARISON_OPERATOR': '>', 'VALUE': '2020-01-01'}}, {'FILTER_BLOCK': {'COLUMNS': ['date'], 'COMPARISON_OPERATOR': '<', 'VALUE': '2021-01-01'}}, {'SCALAR_BLOCK': {'COLUMNS': ['price'], 'OPERATOR': 'COLUMN_SUM', 'AS': 'total_price'}}]}
# PQL validation errors: []
# PQL: {'VERSION': 'v0.1.0', 'NAME': 'Total Price of Specific Orders', 'DESCRIPTION': 'Calculate the total price of orders with quantity greater than 10, price greater than 100, and order date between 2020-01-01 and 2021-01-01.', 'TABLE': 'Orders_oct_12_2024_20_00', 'BLOCKS': [{'FILTER_BLOCK': {'COLUMNS': ['quantity'], 'COMPARISON_OPERATOR': '>', 'VALUE': 10}}, {'FILTER_BLOCK': {'COLUMNS': ['price'], 'COMPARISON_OPERATOR': '>', 'VALUE': 100}}, {'FILTER_BLOCK': {'COLUMNS': ['date'], 'COMPARISON_OPERATOR': '>', 'VALUE': '2020-01-01'}}, {'FILTER_BLOCK': {'COLUMNS': ['date'], 'COMPARISON_OPERATOR': '<', 'VALUE': '2021-01-01'}}, {'SCALAR_BLOCK': {'COLUMNS': ['price'], 'OPERATOR': 'COLUMN_SUM', 'AS': 'total_price'}}]}
# filter block
# {'FILTER_BLOCK': {'COLUMNS': ['quantity'], 'COMPARISON_OPERATOR': '>', 'VALUE': 10}}
#
#             `latest_table_1f320637206741ceb7534de43de60845` AS (
#                 SELECT *
#                 FROM `latest_table_53f507de38244da59370aa97a9245b4d`
#                 WHERE `quantity` > 10
#             )
#          `quantity` > 10 AND
# filter block
# {'FILTER_BLOCK': {'COLUMNS': ['price'], 'COMPARISON_OPERATOR': '>', 'VALUE': 100}}
#
#             `latest_table_aa1cab718ebf4eb38175589cb99e4d69` AS (
#                 SELECT *
#                 FROM `latest_table_1f320637206741ceb7534de43de60845`
#                 WHERE `price` > 100
#             )
#          `price` > 100 AND
# filter block
# {'FILTER_BLOCK': {'COLUMNS': ['date'], 'COMPARISON_OPERATOR': '>', 'VALUE': '2020-01-01'}}
#
#             `latest_table_8afbe7f0e7d04d2c9f0b7c121ca7f85c` AS (
#                 SELECT *
#                 FROM `latest_table_aa1cab718ebf4eb38175589cb99e4d69`
#                 WHERE `date` > '2020-01-01'
#             )
#          `date` > '2020-01-01' AND
# filter block
# {'FILTER_BLOCK': {'COLUMNS': ['date'], 'COMPARISON_OPERATOR': '<', 'VALUE': '2021-01-01'}}
#
#             `latest_table_e71aeaad7bc14347a18d87f6732daf5f` AS (
#                 SELECT *
#                 FROM `latest_table_8afbe7f0e7d04d2c9f0b7c121ca7f85c`
#                 WHERE `date` < '2021-01-01'
#             )
#          `date` < '2021-01-01' AND
# WITH
# `latest_table_53f507de38244da59370aa97a9245b4d` AS (
# SELECT * FROM `Orders_oct_12_2024_20_00`
# ),
#
#             `latest_table_1f320637206741ceb7534de43de60845` AS (
#                 SELECT *
#                 FROM `latest_table_53f507de38244da59370aa97a9245b4d`
#                 WHERE `quantity` > 10
#             )
#         ,
#             `latest_table_aa1cab718ebf4eb38175589cb99e4d69` AS (
#                 SELECT *
#                 FROM `latest_table_1f320637206741ceb7534de43de60845`
#                 WHERE `price` > 100
#             )
#         ,
#             `latest_table_8afbe7f0e7d04d2c9f0b7c121ca7f85c` AS (
#                 SELECT *
#                 FROM `latest_table_aa1cab718ebf4eb38175589cb99e4d69`
#                 WHERE `date` > '2020-01-01'
#             )
#         ,
#             `latest_table_e71aeaad7bc14347a18d87f6732daf5f` AS (
#                 SELECT *
#                 FROM `latest_table_8afbe7f0e7d04d2c9f0b7c121ca7f85c`
#                 WHERE `date` < '2021-01-01'
#             )
#
#             SELECT SUM(`price`) AS `total_price`
#             FROM `latest_table_e71aeaad7bc14347a18d87f6732daf5f`;

# %%
runs
# Out:
# {'pql_version': 'v0.1.0',
#  'eval_time': '2024-10-12T22:08:20.602338',
#  'eval_config': {'model': 'OPEN_AI_MODEL',
#   'table_name_provided': True,
#   'table_descrition_provided': False,
#   'column_names_provided': True,
#   'column_descriptions_provided': False,
#   'column_dtypes_provided': True},
#  'assistant': 'asst_1Z7wPRRU5nxP7P7BYWyXX25m',
#  'runs': {'simple_questions': [{'success': True,
#     'message': {'VERSION': 'v0.1.0',
#      'NAME': 'Total Price',
#      'DESCRIPTION': 'The total price of all orders. Calculated by taking the sum of the price column',
#      'TABLE': 'Orders_oct_12_2024_20_00',
#      'BLOCKS': [{'SCALAR_BLOCK': {'COLUMNS': ['price'],
#         'OPERATOR': 'COLUMN_SUM',
#         'AS': 'total_price'}}]},
#     'chat_id': 1,
#     'thread_id': 'thread_o0NxadqORA2zoDzyswKwNjAq',
#     'full_conversation': [{'initial_user_message': 'What is the total price?'},
#      {'enhanced_user_message': 'Please provide me with a PQL in JSON format that can answer this question, keep it in one JSON and do not add any other text:The following is the table information: Table information:\n\nTable name: Orders_oct_12_2024_20_00\n\nTable description: \n\n\nThe following is the column information in the table: Column information:\nColumn name: order_id\n\n    Column description: \n\n    Column data type: string\n\nColumn name: quantity\n\n    Column description: \n\n    Column data type: float\n\nColumn name: date\n\n    Column description: \n\n    Column data type: date\n\nColumn name: price\n\n    Column description: \n\n    Column data type: float\n\nColumn name: material\n\n    Column description: \n\n    Column data type: string\n\nColumn name: customer\n\n    Column description: \n\n    Column data type: string\n\n\nWhat is the total price?'},
#      {'agent_response_on_retry_1': '```json\n{\n    "VERSION": "v0.1.0",\n    "NAME": "Total Price",\n    "DESCRIPTION": "The total price of all orders. Calculated by taking the sum of the price column",\n    "TABLE": "Orders_oct_12_2024_20_00",\n    "BLOCKS": [\n        {\n            "SCALAR_BLOCK": {\n                "COLUMNS": ["price"],\n                "OPERATOR": "COLUMN_SUM",\n                "AS": "total_price"\n            }\n        }\n    ]\n}\n```'},
#      {'pql_extracted_on_retry_1': {'VERSION': 'v0.1.0',
#        'NAME': 'Total Price',
#        'DESCRIPTION': 'The total price of all orders. Calculated by taking the sum of the price column',
#        'TABLE': 'Orders_oct_12_2024_20_00',
#        'BLOCKS': [{'SCALAR_BLOCK': {'COLUMNS': ['price'],
#           'OPERATOR': 'COLUMN_SUM',
#           'AS': 'total_price'}}]}}],
#     'input_tokens': 13496,
#     'output_tokens': 149,
#     'retries': 1,
#     'start_time': datetime.datetime(2024, 10, 12, 22, 8, 21, 931967),
#     'end_time': datetime.datetime(2024, 10, 12, 22, 8, 28, 259267),
#     'run_details': {'id': 'run_4Z3m0gPIKcmIcX0sthith7MC',
#      'assistant_id': 'asst_1Z7wPRRU5nxP7P7BYWyXX25m',
#      'cancelled_at': None,
#      'completed_at': 1728767306,
#      'created_at': 1728767302,
#      'expires_at': None,
#      'failed_at': None,
#      'incomplete_details': None,
#      'instructions': 'You are a helpful assistant that generates PQL (Processly Query Language) queries.  You use your  PQL knowledge from files you have been provided',
#      'last_error': None,
#      'max_completion_tokens': None,
#      'max_prompt_tokens': None,
#      'metadata': {},
#      'model': 'gpt-4o',
#      'object': 'thread.run',
#      'parallel_tool_calls': True,
#      'required_action': None,
#      'response_format': {'type': 'text'},
#      'started_at': 1728767302,
#      'status': 'completed',
#      'thread_id': 'thread_o0NxadqORA2zoDzyswKwNjAq',
#      'tool_choice': 'auto',
#      'tools': [{'type': 'file_search',
#        'file_search': {'ranking_options': {'score_threshold': 0.0,
#          'ranker': 'default_2024_08_21'}}}],
#      'truncation_strategy': {'type': 'auto', 'last_messages': None},
#      'usage': {'completion_tokens': 149,
#       'prompt_tokens': 13496,
#       'total_tokens': 13645},
#      'temperature': 0.5,
#      'top_p': 1.0,
#      'tool_resources': {}},
#     'sql': 'WITH \n`latest_table_1ad9b55165074b578cc34c3b02fb52a6` AS (\nSELECT * FROM `Orders_oct_12_2024_20_00`\n)\n            SELECT SUM(`price`) AS `total_price`\n            FROM `latest_table_1ad9b55165074b578cc34c3b02fb52a6`;\n        ',
#     'sql_execution_status': True,
#     'sql_execution_result': [{'total_price': 2841.770004272461}],
#     'sql_execution_value': 2841.770004272461,
#     'expected_value': 2841.770004272461},
#    {'success': True,
#     'message': {'VERSION': 'v0.1.0',
#      'NAME': 'Total Price of Orders with Quantity Greater than 10',
#      'DESCRIPTION': 'Calculate the total price of orders where the quantity is greater than 10.',
#      'TABLE': 'Orders_oct_12_2024_20_00',
#      'BLOCKS': [{'FILTER_BLOCK': {'COLUMNS': ['quantity'],
#         'COMPARISON_OPERATOR': '>',
#         'VALUE': 10}},
#       {'SCALAR_BLOCK': {'COLUMNS': ['price'],
#         'OPERATOR': 'COLUMN_SUM',
#         'AS': 'total_price'}}]},
#     'chat_id': 2,
#     'thread_id': 'thread_8WlUv59yUom38vEl8qD2ROPZ',
#     'full_conversation': [{'initial_user_message': 'What is the total price of orders with quantity greater than 10?'},
#      {'enhanced_user_message': 'Please provide me with a PQL in JSON format that can answer this question, keep it in one JSON and do not add any other text:The following is the table information: Table information:\n\nTable name: Orders_oct_12_2024_20_00\n\nTable description: \n\n\nThe following is the column information in the table: Column information:\nColumn name: order_id\n\n    Column description: \n\n    Column data type: string\n\nColumn name: quantity\n\n    Column description: \n\n    Column data type: float\n\nColumn name: date\n\n    Column description: \n\n    Column data type: date\n\nColumn name: price\n\n    Column description: \n\n    Column data type: float\n\nColumn name: material\n\n    Column description: \n\n    Column data type: string\n\nColumn name: customer\n\n    Column description: \n\n    Column data type: string\n\n\nWhat is the total price of orders with quantity greater than 10?'},
#      {'agent_response_on_retry_1': '```json\n{\n    "VERSION": "v0.1.0",\n    "NAME": "Total Price of Orders with Quantity Greater than 10",\n    "DESCRIPTION": "Calculate the total price of orders where the quantity is greater than 10.",\n    "TABLE": "Orders_oct_12_2024_20_00",\n    "BLOCKS": [\n        {\n            "FILTER_BLOCK": {\n                "COLUMNS": ["quantity"],\n                "COMPARISON_OPERATOR": ">",\n                "VALUE": 10\n            }\n        },\n        {\n            "SCALAR_BLOCK": {\n                "COLUMNS": ["price"],\n                "OPERATOR": "COLUMN_SUM",\n                "AS": "total_price"\n            }\n        }\n    ]\n}\n```'},
#      {'pql_extracted_on_retry_1': {'VERSION': 'v0.1.0',
#        'NAME': 'Total Price of Orders with Quantity Greater than 10',
#        'DESCRIPTION': 'Calculate the total price of orders where the quantity is greater than 10.',
#        'TABLE': 'Orders_oct_12_2024_20_00',
#        'BLOCKS': [{'FILTER_BLOCK': {'COLUMNS': ['quantity'],
#           'COMPARISON_OPERATOR': '>',
#           'VALUE': 10}},
#         {'SCALAR_BLOCK': {'COLUMNS': ['price'],
#           'OPERATOR': 'COLUMN_SUM',
#           'AS': 'total_price'}}]}}],
#     'input_tokens': 13506,
#     'output_tokens': 184,
#     'retries': 1,
#     'start_time': datetime.datetime(2024, 10, 12, 22, 8, 28, 978655),
#     'end_time': datetime.datetime(2024, 10, 12, 22, 8, 35, 818023),
#     'run_details': {'id': 'run_3bBKMEc6LUFlvzG3L4YLZyE5',
#      'assistant_id': 'asst_1Z7wPRRU5nxP7P7BYWyXX25m',
#      'cancelled_at': None,
#      'completed_at': 1728767314,
#      'created_at': 1728767309,
#      'expires_at': None,
#      'failed_at': None,
#      'incomplete_details': None,
#      'instructions': 'You are a helpful assistant that generates PQL (Processly Query Language) queries.  You use your  PQL knowledge from files you have been provided',
#      'last_error': None,
#      'max_completion_tokens': None,
#      'max_prompt_tokens': None,
#      'metadata': {},
#      'model': 'gpt-4o',
#      'object': 'thread.run',
#      'parallel_tool_calls': True,
#      'required_action': None,
#      'response_format': {'type': 'text'},
#      'started_at': 1728767309,
#      'status': 'completed',
#      'thread_id': 'thread_8WlUv59yUom38vEl8qD2ROPZ',
#      'tool_choice': 'auto',
#      'tools': [{'type': 'file_search',
#        'file_search': {'ranking_options': {'score_threshold': 0.0,
#          'ranker': 'default_2024_08_21'}}}],
#      'truncation_strategy': {'type': 'auto', 'last_messages': None},
#      'usage': {'completion_tokens': 184,
#       'prompt_tokens': 13506,
#       'total_tokens': 13690},
#      'temperature': 0.5,
#      'top_p': 1.0,
#      'tool_resources': {}},
#     'sql': 'WITH \n`latest_table_e7c22428d834437c8f1ed94f24b69614` AS (\nSELECT * FROM `Orders_oct_12_2024_20_00`\n),\n\n            `latest_table_7ef39604636545a5b759aacc6380d930` AS (\n                SELECT *\n                FROM `latest_table_e7c22428d834437c8f1ed94f24b69614`\n                WHERE `quantity` > 10\n            )\n        \n            SELECT SUM(`price`) AS `total_price`\n            FROM `latest_table_7ef39604636545a5b759aacc6380d930`;\n        ',
#     'sql_execution_status': True,
#     'sql_execution_result': [{'total_price': 2755.770004272461}],
#     'sql_execution_value': 2755.770004272461,
#     'expected_value': 2755.770004272461},
#    {'success': True,
#     'message': {'VERSION': 'v0.1.0',
#      'NAME': 'Total Price of Orders with Quantity > 10 and Price > 100',
#      'DESCRIPTION': 'Calculate the total price of orders where the quantity is greater than 10 and the price is greater than 100.',
#      'TABLE': 'Orders_oct_12_2024_20_00',
#      'BLOCKS': [{'FILTER_BLOCK': {'COLUMNS': ['quantity'],
#         'COMPARISON_OPERATOR': '>',
#         'VALUE': 10}},
#       {'FILTER_BLOCK': {'COLUMNS': ['price'],
#         'COMPARISON_OPERATOR': '>',
#         'VALUE': 100}},
#       {'SCALAR_BLOCK': {'COLUMNS': ['price'],
#         'OPERATOR': 'COLUMN_SUM',
#         'AS': 'total_price'}}]},
#     'chat_id': 3,
#     'thread_id': 'thread_aL9r0TkSyabwqBe8dQaLbOfa',
#     'full_conversation': [{'initial_user_message': 'What is the total price of orders with quantity greater than 10 and price greater than 100?'},
#      {'enhanced_user_message': 'Please provide me with a PQL in JSON format that can answer this question, keep it in one JSON and do not add any other text:The following is the table information: Table information:\n\nTable name: Orders_oct_12_2024_20_00\n\nTable description: \n\n\nThe following is the column information in the table: Column information:\nColumn name: order_id\n\n    Column description: \n\n    Column data type: string\n\nColumn name: quantity\n\n    Column description: \n\n    Column data type: float\n\nColumn name: date\n\n    Column description: \n\n    Column data type: date\n\nColumn name: price\n\n    Column description: \n\n    Column data type: float\n\nColumn name: material\n\n    Column description: \n\n    Column data type: string\n\nColumn name: customer\n\n    Column description: \n\n    Column data type: string\n\n\nWhat is the total price of orders with quantity greater than 10 and price greater than 100?'},
#      {'agent_response_on_retry_1': '```json\n{\n    "VERSION": "v0.1.0",\n    "NAME": "Total Price of Orders with Quantity > 10 and Price > 100",\n    "DESCRIPTION": "Calculate the total price of orders where the quantity is greater than 10 and the price is greater than 100.",\n    "TABLE": "Orders_oct_12_2024_20_00",\n    "BLOCKS": [\n        {\n            "FILTER_BLOCK": {\n                "COLUMNS": ["quantity", "price"],\n                "COMPARISON_OPERATOR": ">",\n                "VALUE": [10, 100]\n            }\n        },\n        {\n            "SCALAR_BLOCK": {\n                "COLUMNS": ["price"],\n                "OPERATOR": "COLUMN_SUM",\n                "AS": "total_price"\n            }\n        }\n    ]\n}\n```'},
#      {'pql_extracted_on_retry_1': {'VERSION': 'v0.1.0',
#        'NAME': 'Total Price of Orders with Quantity > 10 and Price > 100',
#        'DESCRIPTION': 'Calculate the total price of orders where the quantity is greater than 10 and the price is greater than 100.',
#        'TABLE': 'Orders_oct_12_2024_20_00',
#        'BLOCKS': [{'FILTER_BLOCK': {'COLUMNS': ['quantity', 'price'],
#           'COMPARISON_OPERATOR': '>',
#           'VALUE': [10, 100]}},
#         {'SCALAR_BLOCK': {'COLUMNS': ['price'],
#           'OPERATOR': 'COLUMN_SUM',
#           'AS': 'total_price'}}]}},
#      {'pql_error_on_retry_1': 'PQL validation failed\n errors: Invalid value for block at index 0: [10, 100] for VALUE, value can not be a collection'},
#      {'agent_response_on_retry_2': '```json\n{\n    "VERSION": "v0.1.0",\n    "NAME": "Total Price of Orders with Quantity > 10 and Price > 100",\n    "DESCRIPTION": "Calculate the total price of orders where the quantity is greater than 10 and the price is greater than 100.",\n    "TABLE": "Orders_oct_12_2024_20_00",\n    "BLOCKS": [\n        {\n            "FILTER_BLOCK": {\n                "COLUMNS": ["quantity"],\n                "COMPARISON_OPERATOR": ">",\n                "VALUE": 10\n            }\n        },\n        {\n            "FILTER_BLOCK": {\n                "COLUMNS": ["price"],\n                "COMPARISON_OPERATOR": ">",\n                "VALUE": 100\n            }\n        },\n        {\n            "SCALAR_BLOCK": {\n                "COLUMNS": ["price"],\n                "OPERATOR": "COLUMN_SUM",\n                "AS": "total_price"\n            }\n        }\n    ]\n}\n```'},
#      {'pql_extracted_on_retry_2': {'VERSION': 'v0.1.0',
#        'NAME': 'Total Price of Orders with Quantity > 10 and Price > 100',
#        'DESCRIPTION': 'Calculate the total price of orders where the quantity is greater than 10 and the price is greater than 100.',
#        'TABLE': 'Orders_oct_12_2024_20_00',
#        'BLOCKS': [{'FILTER_BLOCK': {'COLUMNS': ['quantity'],
#           'COMPARISON_OPERATOR': '>',
#           'VALUE': 10}},
#         {'FILTER_BLOCK': {'COLUMNS': ['price'],
#           'COMPARISON_OPERATOR': '>',
#           'VALUE': 100}},
#         {'SCALAR_BLOCK': {'COLUMNS': ['price'],
#           'OPERATOR': 'COLUMN_SUM',
#           'AS': 'total_price'}}]}}],
#     'input_tokens': 1316,
#     'output_tokens': 203,
#     'retries': 2,
#     'start_time': datetime.datetime(2024, 10, 12, 22, 8, 43, 555371),
#     'end_time': datetime.datetime(2024, 10, 12, 22, 8, 47, 81666),
#     'run_details': {'id': 'run_3YroiSQA3PTEAdtri0Zaj5fu',
#      'assistant_id': 'asst_1Z7wPRRU5nxP7P7BYWyXX25m',
#      'cancelled_at': None,
#      'completed_at': 1728767326,
#      'created_at': 1728767323,
#      'expires_at': None,
#      'failed_at': None,
#      'incomplete_details': None,
#      'instructions': 'You are a helpful assistant that generates PQL (Processly Query Language) queries.  You use your  PQL knowledge from files you have been provided',
#      'last_error': None,
#      'max_completion_tokens': None,
#      'max_prompt_tokens': None,
#      'metadata': {},
#      'model': 'gpt-4o',
#      'object': 'thread.run',
#      'parallel_tool_calls': True,
#      'required_action': None,
#      'response_format': {'type': 'text'},
#      'started_at': 1728767324,
#      'status': 'completed',
#      'thread_id': 'thread_aL9r0TkSyabwqBe8dQaLbOfa',
#      'tool_choice': 'auto',
#      'tools': [{'type': 'file_search',
#        'file_search': {'ranking_options': {'score_threshold': 0.0,
#          'ranker': 'default_2024_08_21'}}}],
#      'truncation_strategy': {'type': 'auto', 'last_messages': None},
#      'usage': {'completion_tokens': 203,
#       'prompt_tokens': 1316,
#       'total_tokens': 1519},
#      'temperature': 0.5,
#      'top_p': 1.0,
#      'tool_resources': {}},
#     'sql': 'WITH \n`latest_table_1c1419244cbf484fae8997765b5871ac` AS (\nSELECT * FROM `Orders_oct_12_2024_20_00`\n),\n\n            `latest_table_1b653f20ffb34d9f8655f0f5cfa1953e` AS (\n                SELECT *\n                FROM `latest_table_1c1419244cbf484fae8997765b5871ac`\n                WHERE `quantity` > 10\n            )\n        ,\n            `latest_table_58fe4db8fdc143159c794cf365ed7d39` AS (\n                SELECT *\n                FROM `latest_table_1b653f20ffb34d9f8655f0f5cfa1953e`\n                WHERE `price` > 100\n            )\n        \n            SELECT SUM(`price`) AS `total_price`\n            FROM `latest_table_58fe4db8fdc143159c794cf365ed7d39`;\n        ',
#     'sql_execution_status': True,
#     'sql_execution_result': [{'total_price': 2162.770004272461}],
#     'sql_execution_value': 2162.770004272461,
#     'expected_value': 2162.770004272461}],
#   'medium_questions': [{'success': True,
#     'message': {'VERSION': 'v0.1.0',
#      'NAME': 'Total Price of Orders',
#      'DESCRIPTION': 'The total price of orders with quantity greater than 10, price greater than 100, and order date after 2020-01-01.',
#      'TABLE': 'Orders_oct_12_2024_20_00',
#      'BLOCKS': [{'FILTER_BLOCK': {'COLUMNS': ['quantity'],
#         'COMPARISON_OPERATOR': '>',
#         'VALUE': 10}},
#       {'FILTER_BLOCK': {'COLUMNS': ['price'],
#         'COMPARISON_OPERATOR': '>',
#         'VALUE': 100}},
#       {'FILTER_BLOCK': {'COLUMNS': ['date'],
#         'COMPARISON_OPERATOR': '>',
#         'VALUE': '2020-01-01'}},
#       {'SCALAR_BLOCK': {'COLUMNS': ['price'],
#         'OPERATOR': 'COLUMN_SUM',
#         'AS': 'total_price'}}]},
#     'chat_id': 1,
#     'thread_id': 'thread_E9EDzW920mHb0RqkoZ0riMCA',
#     'full_conversation': [{'initial_user_message': 'What is the total price of orders with quantity greater than 10 and price greater than 100 and order date greater than 2020-01-01?'},
#      {'enhanced_user_message': 'Please provide me with a PQL in JSON format that can answer this question, keep it in one JSON and do not add any other text:The following is the table information: Table information:\n\nTable name: Orders_oct_12_2024_20_00\n\nTable description: \n\n\nThe following is the column information in the table: Column information:\nColumn name: order_id\n\n    Column description: \n\n    Column data type: string\n\nColumn name: quantity\n\n    Column description: \n\n    Column data type: float\n\nColumn name: date\n\n    Column description: \n\n    Column data type: date\n\nColumn name: price\n\n    Column description: \n\n    Column data type: float\n\nColumn name: material\n\n    Column description: \n\n    Column data type: string\n\nColumn name: customer\n\n    Column description: \n\n    Column data type: string\n\n\nWhat is the total price of orders with quantity greater than 10 and price greater than 100 and order date greater than 2020-01-01?'},
#      {'agent_response_on_retry_1': '```json\n{\n    "VERSION": "v0.1.0",\n    "NAME": "Total Price of Orders",\n    "DESCRIPTION": "The total price of orders with quantity greater than 10, price greater than 100, and order date after 2020-01-01.",\n    "TABLE": "Orders_oct_12_2024_20_00",\n    "BLOCKS": [\n        {\n            "FILTER_BLOCK": {\n                "COLUMNS": ["quantity", "price", "date"],\n                "COMPARISON_OPERATOR": ">",\n                "VALUE": [10, 100, "2020-01-01"]\n            }\n        },\n        {\n            "SCALAR_BLOCK": {\n                "COLUMNS": ["price"],\n                "OPERATOR": "COLUMN_SUM",\n                "AS": "total_price"\n            }\n        }\n    ]\n}\n```'},
#      {'pql_extracted_on_retry_1': {'VERSION': 'v0.1.0',
#        'NAME': 'Total Price of Orders',
#        'DESCRIPTION': 'The total price of orders with quantity greater than 10, price greater than 100, and order date after 2020-01-01.',
#        'TABLE': 'Orders_oct_12_2024_20_00',
#        'BLOCKS': [{'FILTER_BLOCK': {'COLUMNS': ['quantity', 'price', 'date'],
#           'COMPARISON_OPERATOR': '>',
#           'VALUE': [10, 100, '2020-01-01']}},
#         {'SCALAR_BLOCK': {'COLUMNS': ['price'],
#           'OPERATOR': 'COLUMN_SUM',
#           'AS': 'total_price'}}]}},
#      {'pql_error_on_retry_1': "PQL validation failed\n errors: Invalid value for block at index 0: [10, 100, '2020-01-01'] for VALUE, value can not be a collection"},
#      {'agent_response_on_retry_2': '```json\n{\n    "VERSION": "v0.1.0",\n    "NAME": "Total Price of Orders",\n    "DESCRIPTION": "The total price of orders with quantity greater than 10, price greater than 100, and order date after 2020-01-01.",\n    "TABLE": "Orders_oct_12_2024_20_00",\n    "BLOCKS": [\n        {\n            "FILTER_BLOCK": {\n                "AND": [\n                    {\n                        "COLUMN": "quantity",\n                        "COMPARISON_OPERATOR": ">",\n                        "VALUE": 10\n                    },\n                    {\n                        "COLUMN": "price",\n                        "COMPARISON_OPERATOR": ">",\n                        "VALUE": 100\n                    },\n                    {\n                        "COLUMN": "date",\n                        "COMPARISON_OPERATOR": ">",\n                        "VALUE": "2020-01-01"\n                    }\n                ]\n            }\n        },\n        {\n            "SCALAR_BLOCK": {\n                "COLUMN": "price",\n                "OPERATOR": "COLUMN_SUM",\n                "AS": "total_price"\n            }\n        }\n    ]\n}\n```'},
#      {'pql_extracted_on_retry_2': {'VERSION': 'v0.1.0',
#        'NAME': 'Total Price of Orders',
#        'DESCRIPTION': 'The total price of orders with quantity greater than 10, price greater than 100, and order date after 2020-01-01.',
#        'TABLE': 'Orders_oct_12_2024_20_00',
#        'BLOCKS': [{'FILTER_BLOCK': {'AND': [{'COLUMN': 'quantity',
#             'COMPARISON_OPERATOR': '>',
#             'VALUE': 10},
#            {'COLUMN': 'price', 'COMPARISON_OPERATOR': '>', 'VALUE': 100},
#            {'COLUMN': 'date',
#             'COMPARISON_OPERATOR': '>',
#             'VALUE': '2020-01-01'}]}},
#         {'SCALAR_BLOCK': {'COLUMN': 'price',
#           'OPERATOR': 'COLUMN_SUM',
#           'AS': 'total_price'}}]}},
#      {'pql_error_on_retry_2': "PQL validation failed\n errors: Invalid key: AND at BLOCKS[0].FILTER_BLOCK.AND, valid keys are: ['TABLE', 'BLOCKS', 'EXTENSION_BLOCKS', 'COLUMNS', 'OPERATOR', 'AS', 'GROUP_BY', 'GROUPING_OPERATORS', 'GROUPING_BLOCK', 'FILTER_BLOCK', 'COMPARISON_OPERATOR', 'VALUE', 'SCALAR_BLOCK', 'VERSION', 'DESCRIPTION', 'NAME']\nInvalid key: COLUMN at BLOCKS[0].FILTER_BLOCK.AND[0].COLUMN, valid keys are: ['TABLE', 'BLOCKS', 'EXTENSION_BLOCKS', 'COLUMNS', 'OPERATOR', 'AS', 'GROUP_BY', 'GROUPING_OPERATORS', 'GROUPING_BLOCK', 'FILTER_BLOCK', 'COMPARISON_OPERATOR', 'VALUE', 'SCALAR_BLOCK', 'VERSION', 'DESCRIPTION', 'NAME']\nInvalid key: COLUMN at BLOCKS[0].FILTER_BLOCK.AND[1].COLUMN, valid keys are: ['TABLE', 'BLOCKS', 'EXTENSION_BLOCKS', 'COLUMNS', 'OPERATOR', 'AS', 'GROUP_BY', 'GROUPING_OPERATORS', 'GROUPING_BLOCK', 'FILTER_BLOCK', 'COMPARISON_OPERATOR', 'VALUE', 'SCALAR_BLOCK', 'VERSION', 'DESCRIPTION', 'NAME']\nInvalid key: COLUMN at BLOCKS[0].FILTER_BLOCK.AND[2].COLUMN, valid keys are: ['TABLE', 'BLOCKS', 'EXTENSION_BLOCKS', 'COLUMNS', 'OPERATOR', 'AS', 'GROUP_BY', 'GROUPING_OPERATORS', 'GROUPING_BLOCK', 'FILTER_BLOCK', 'COMPARISON_OPERATOR', 'VALUE', 'SCALAR_BLOCK', 'VERSION', 'DESCRIPTION', 'NAME']\nInvalid key: COLUMN at BLOCKS[1].SCALAR_BLOCK.COLUMN, valid keys are: ['TABLE', 'BLOCKS', 'EXTENSION_BLOCKS', 'COLUMNS', 'OPERATOR', 'AS', 'GROUP_BY', 'GROUPING_OPERATORS', 'GROUPING_BLOCK', 'FILTER_BLOCK', 'COMPARISON_OPERATOR', 'VALUE', 'SCALAR_BLOCK', 'VERSION', 'DESCRIPTION', 'NAME']\nMissing key for block at index 0: COLUMNS, required keys are: ['COLUMNS', 'COMPARISON_OPERATOR', 'VALUE']\nMissing key for block at index 0: COMPARISON_OPERATOR, required keys are: ['COLUMNS', 'COMPARISON_OPERATOR', 'VALUE']\nMissing key for block at index 0: VALUE, required keys are: ['COLUMNS', 'COMPARISON_OPERATOR', 'VALUE']\nInvalid key for block at index 0: AND, valid keys are: ['COLUMNS', 'COMPARISON_OPERATOR', 'VALUE']\nInvalid key for block at index 0: AND\nMissing key for block at index 1: COLUMNS, required keys are: ['COLUMNS', 'OPERATOR', 'AS']\nInvalid key for block at index 1: COLUMN, valid keys are: ['COLUMNS', 'OPERATOR', 'AS']\nInvalid key for block at index 1: COLUMN"},
#      {'agent_response_on_retry_3': '```json\n{\n    "VERSION": "v0.1.0",\n    "NAME": "Total Price of Orders",\n    "DESCRIPTION": "The total price of orders with quantity greater than 10, price greater than 100, and order date after 2020-01-01.",\n    "TABLE": "Orders_oct_12_2024_20_00",\n    "BLOCKS": [\n        {\n            "FILTER_BLOCK": {\n                "COLUMNS": ["quantity"],\n                "COMPARISON_OPERATOR": ">",\n                "VALUE": 10\n            }\n        },\n        {\n            "FILTER_BLOCK": {\n                "COLUMNS": ["price"],\n                "COMPARISON_OPERATOR": ">",\n                "VALUE": 100\n            }\n        },\n        {\n            "FILTER_BLOCK": {\n                "COLUMNS": ["date"],\n                "COMPARISON_OPERATOR": ">",\n                "VALUE": "2020-01-01"\n            }\n        },\n        {\n            "SCALAR_BLOCK": {\n                "COLUMNS": ["price"],\n                "OPERATOR": "COLUMN_SUM",\n                "AS": "total_price"\n            }\n        }\n    ]\n}\n```'},
#      {'pql_extracted_on_retry_3': {'VERSION': 'v0.1.0',
#        'NAME': 'Total Price of Orders',
#        'DESCRIPTION': 'The total price of orders with quantity greater than 10, price greater than 100, and order date after 2020-01-01.',
#        'TABLE': 'Orders_oct_12_2024_20_00',
#        'BLOCKS': [{'FILTER_BLOCK': {'COLUMNS': ['quantity'],
#           'COMPARISON_OPERATOR': '>',
#           'VALUE': 10}},
#         {'FILTER_BLOCK': {'COLUMNS': ['price'],
#           'COMPARISON_OPERATOR': '>',
#           'VALUE': 100}},
#         {'FILTER_BLOCK': {'COLUMNS': ['date'],
#           'COMPARISON_OPERATOR': '>',
#           'VALUE': '2020-01-01'}},
#         {'SCALAR_BLOCK': {'COLUMNS': ['price'],
#           'OPERATOR': 'COLUMN_SUM',
#           'AS': 'total_price'}}]}}],
#     'input_tokens': 2216,
#     'output_tokens': 241,
#     'retries': 3,
#     'start_time': datetime.datetime(2024, 10, 12, 22, 8, 59, 250362),
#     'end_time': datetime.datetime(2024, 10, 12, 22, 9, 4, 154926),
#     'run_details': {'id': 'run_Kvt4wXz2NlOnLKhDWitJCiFj',
#      'assistant_id': 'asst_1Z7wPRRU5nxP7P7BYWyXX25m',
#      'cancelled_at': None,
#      'completed_at': 1728767343,
#      'created_at': 1728767339,
#      'expires_at': None,
#      'failed_at': None,
#      'incomplete_details': None,
#      'instructions': 'You are a helpful assistant that generates PQL (Processly Query Language) queries.  You use your  PQL knowledge from files you have been provided',
#      'last_error': None,
#      'max_completion_tokens': None,
#      'max_prompt_tokens': None,
#      'metadata': {},
#      'model': 'gpt-4o',
#      'object': 'thread.run',
#      'parallel_tool_calls': True,
#      'required_action': None,
#      'response_format': {'type': 'text'},
#      'started_at': 1728767339,
#      'status': 'completed',
#      'thread_id': 'thread_E9EDzW920mHb0RqkoZ0riMCA',
#      'tool_choice': 'auto',
#      'tools': [{'type': 'file_search',
#        'file_search': {'ranking_options': {'score_threshold': 0.0,
#          'ranker': 'default_2024_08_21'}}}],
#      'truncation_strategy': {'type': 'auto', 'last_messages': None},
#      'usage': {'completion_tokens': 241,
#       'prompt_tokens': 2216,
#       'total_tokens': 2457},
#      'temperature': 0.5,
#      'top_p': 1.0,
#      'tool_resources': {}},
#     'sql': "WITH \n`latest_table_071cac5ad2b24d87a397e2fdfedbccb0` AS (\nSELECT * FROM `Orders_oct_12_2024_20_00`\n),\n\n            `latest_table_bde7af1e7cd54c5f86d3e1c2e92e9361` AS (\n                SELECT *\n                FROM `latest_table_071cac5ad2b24d87a397e2fdfedbccb0`\n                WHERE `quantity` > 10\n            )\n        ,\n            `latest_table_148ad5bd26c3482993b4a9c13285e3a9` AS (\n                SELECT *\n                FROM `latest_table_bde7af1e7cd54c5f86d3e1c2e92e9361`\n                WHERE `price` > 100\n            )\n        ,\n            `latest_table_8eab3ba335f24c1d8024688704feeadb` AS (\n                SELECT *\n                FROM `latest_table_148ad5bd26c3482993b4a9c13285e3a9`\n                WHERE `date` > '2020-01-01'\n            )\n        \n            SELECT SUM(`price`) AS `total_price`\n            FROM `latest_table_8eab3ba335f24c1d8024688704feeadb`;\n        ",
#     'sql_execution_status': True,
#     'sql_execution_result': [{'total_price': 1097.770004272461}],
#     'sql_execution_value': 1097.770004272461,
#     'expected_value': 1097.770004272461},
#    {'success': True,
#     'message': {'VERSION': 'v0.1.0',
#      'NAME': 'Total Price of Specific Orders',
#      'DESCRIPTION': 'Calculate the total price of orders with quantity greater than 10, price greater than 100, and order date between 2020-01-01 and 2021-01-01.',
#      'TABLE': 'Orders_oct_12_2024_20_00',
#      'BLOCKS': [{'FILTER_BLOCK': {'COLUMNS': ['quantity'],
#         'COMPARISON_OPERATOR': '>',
#         'VALUE': 10}},
#       {'FILTER_BLOCK': {'COLUMNS': ['price'],
#         'COMPARISON_OPERATOR': '>',
#         'VALUE': 100}},
#       {'FILTER_BLOCK': {'COLUMNS': ['date'],
#         'COMPARISON_OPERATOR': '>',
#         'VALUE': '2020-01-01'}},
#       {'FILTER_BLOCK': {'COLUMNS': ['date'],
#         'COMPARISON_OPERATOR': '<',
#         'VALUE': '2021-01-01'}},
#       {'SCALAR_BLOCK': {'COLUMNS': ['price'],
#         'OPERATOR': 'COLUMN_SUM',
#         'AS': 'total_price'}}]},
#     'chat_id': 2,
#     'thread_id': 'thread_nQ3YHujFsediIByjPHHlwkS0',
#     'full_conversation': [{'initial_user_message': 'What is the total price of orders with quantity greater than 10 and price greater than 100 and order date greater than 2020-01-01 and order date less than 2021-01-01?'},
#      {'enhanced_user_message': 'Please provide me with a PQL in JSON format that can answer this question, keep it in one JSON and do not add any other text:The following is the table information: Table information:\n\nTable name: Orders_oct_12_2024_20_00\n\nTable description: \n\n\nThe following is the column information in the table: Column information:\nColumn name: order_id\n\n    Column description: \n\n    Column data type: string\n\nColumn name: quantity\n\n    Column description: \n\n    Column data type: float\n\nColumn name: date\n\n    Column description: \n\n    Column data type: date\n\nColumn name: price\n\n    Column description: \n\n    Column data type: float\n\nColumn name: material\n\n    Column description: \n\n    Column data type: string\n\nColumn name: customer\n\n    Column description: \n\n    Column data type: string\n\n\nWhat is the total price of orders with quantity greater than 10 and price greater than 100 and order date greater than 2020-01-01 and order date less than 2021-01-01?'},
#      {'agent_response_on_retry_1': '```json\n{\n    "VERSION": "v0.1.0",\n    "NAME": "Total Price of Specific Orders",\n    "DESCRIPTION": "Calculate the total price of orders with quantity greater than 10, price greater than 100, and order date between 2020-01-01 and 2021-01-01.",\n    "TABLE": "Orders_oct_12_2024_20_00",\n    "BLOCKS": [\n        {\n            "FILTER_BLOCK": {\n                "COLUMNS": ["quantity"],\n                "COMPARISON_OPERATOR": ">",\n                "VALUE": 10\n            }\n        },\n        {\n            "FILTER_BLOCK": {\n                "COLUMNS": ["price"],\n                "COMPARISON_OPERATOR": ">",\n                "VALUE": 100\n            }\n        },\n        {\n            "FILTER_BLOCK": {\n                "COLUMNS": ["date"],\n                "COMPARISON_OPERATOR": ">",\n                "VALUE": "2020-01-01"\n            }\n        },\n        {\n            "FILTER_BLOCK": {\n                "COLUMNS": ["date"],\n                "COMPARISON_OPERATOR": "<",\n                "VALUE": "2021-01-01"\n            }\n        },\n        {\n            "SCALAR_BLOCK": {\n                "COLUMNS": ["price"],\n                "OPERATOR": "COLUMN_SUM",\n                "AS": "total_price"\n            }\n        }\n    ]\n}\n```'},
#      {'pql_extracted_on_retry_1': {'VERSION': 'v0.1.0',
#        'NAME': 'Total Price of Specific Orders',
#        'DESCRIPTION': 'Calculate the total price of orders with quantity greater than 10, price greater than 100, and order date between 2020-01-01 and 2021-01-01.',
#        'TABLE': 'Orders_oct_12_2024_20_00',
#        'BLOCKS': [{'FILTER_BLOCK': {'COLUMNS': ['quantity'],
#           'COMPARISON_OPERATOR': '>',
#           'VALUE': 10}},
#         {'FILTER_BLOCK': {'COLUMNS': ['price'],
#           'COMPARISON_OPERATOR': '>',
#           'VALUE': 100}},
#         {'FILTER_BLOCK': {'COLUMNS': ['date'],
#           'COMPARISON_OPERATOR': '>',
#           'VALUE': '2020-01-01'}},
#         {'FILTER_BLOCK': {'COLUMNS': ['date'],
#           'COMPARISON_OPERATOR': '<',
#           'VALUE': '2021-01-01'}},
#         {'SCALAR_BLOCK': {'COLUMNS': ['price'],
#           'OPERATOR': 'COLUMN_SUM',
#           'AS': 'total_price'}}]}}],
#     'input_tokens': 13596,
#     'output_tokens': 351,
#     'retries': 1,
#     'start_time': datetime.datetime(2024, 10, 12, 22, 9, 5, 244359),
#     'end_time': datetime.datetime(2024, 10, 12, 22, 9, 12, 594237),
#     'run_details': {'id': 'run_GXla5yAIliYFdG5DXQmT2QAJ',
#      'assistant_id': 'asst_1Z7wPRRU5nxP7P7BYWyXX25m',
#      'cancelled_at': None,
#      'completed_at': 1728767351,
#      'created_at': 1728767345,
#      'expires_at': None,
#      'failed_at': None,
#      'incomplete_details': None,
#      'instructions': 'You are a helpful assistant that generates PQL (Processly Query Language) queries.  You use your  PQL knowledge from files you have been provided',
#      'last_error': None,
#      'max_completion_tokens': None,
#      'max_prompt_tokens': None,
#      'metadata': {},
#      'model': 'gpt-4o',
#      'object': 'thread.run',
#      'parallel_tool_calls': True,
#      'required_action': None,
#      'response_format': {'type': 'text'},
#      'started_at': 1728767345,
#      'status': 'completed',
#      'thread_id': 'thread_nQ3YHujFsediIByjPHHlwkS0',
#      'tool_choice': 'auto',
#      'tools': [{'type': 'file_search',
#        'file_search': {'ranking_options': {'score_threshold': 0.0,
#          'ranker': 'default_2024_08_21'}}}],
#      'truncation_strategy': {'type': 'auto', 'last_messages': None},
#      'usage': {'completion_tokens': 351,
#       'prompt_tokens': 13596,
#       'total_tokens': 13947},
#      'temperature': 0.5,
#      'top_p': 1.0,
#      'tool_resources': {}},
#     'sql': "WITH \n`latest_table_53f507de38244da59370aa97a9245b4d` AS (\nSELECT * FROM `Orders_oct_12_2024_20_00`\n),\n\n            `latest_table_1f320637206741ceb7534de43de60845` AS (\n                SELECT *\n                FROM `latest_table_53f507de38244da59370aa97a9245b4d`\n                WHERE `quantity` > 10\n            )\n        ,\n            `latest_table_aa1cab718ebf4eb38175589cb99e4d69` AS (\n                SELECT *\n                FROM `latest_table_1f320637206741ceb7534de43de60845`\n                WHERE `price` > 100\n            )\n        ,\n            `latest_table_8afbe7f0e7d04d2c9f0b7c121ca7f85c` AS (\n                SELECT *\n                FROM `latest_table_aa1cab718ebf4eb38175589cb99e4d69`\n                WHERE `date` > '2020-01-01'\n            )\n        ,\n            `latest_table_e71aeaad7bc14347a18d87f6732daf5f` AS (\n                SELECT *\n                FROM `latest_table_8afbe7f0e7d04d2c9f0b7c121ca7f85c`\n                WHERE `date` < '2021-01-01'\n            )\n        \n            SELECT SUM(`price`) AS `total_price`\n            FROM `latest_table_e71aeaad7bc14347a18d87f6732daf5f`;\n        ",
#     'sql_execution_status': True,
#     'sql_execution_result': [{'total_price': None}],
#     'sql_execution_value': None,
#     'expected_value': None}],
#   'complex_questions': []}}

# %%
def datetime_converter(o):
    if isinstance(o, datetime):
        return o.isoformat()
    
with open(eval_result_file_name, 'w') as json_file:
    json.dump(runs, json_file, default=datetime_converter, indent=4)

# %% [markdown]
# #### ad-hoc tests

# %%
_adc_pql = {
                    "VERSION": "v0.1.0",
                    "NAME": "Total Price of Specific Orders",
                    "DESCRIPTION": "Calculate the total price of orders with quantity greater than 10, price greater than 100, and order date between 2020-01-01 and 2021-01-01.",
                    "TABLE": "Orders_oct_12_2024_20_00",
                    "BLOCKS": [
                        {
                            "FILTER_BLOCK": {
                                "COLUMNS": [
                                    "quantity"
                                ],
                                "COMPARISON_OPERATOR": ">",
                                "VALUE": 10
                            }
                        },
                        {
                            "FILTER_BLOCK": {
                                "COLUMNS": [
                                    "price"
                                ],
                                "COMPARISON_OPERATOR": ">",
                                "VALUE": 100
                            }
                        },
                        {
                            "FILTER_BLOCK": {
                                "COLUMNS": [
                                    "date"
                                ],
                                "COMPARISON_OPERATOR": ">",
                                "VALUE": "2020-01-01"
                            }
                        },
                        {
                            "FILTER_BLOCK": {
                                "COLUMNS": [
                                    "date"
                                ],
                                "COMPARISON_OPERATOR": "<",
                                "VALUE": "2021-01-01"
                            }
                        },
                        {
                            "SCALAR_BLOCK": {
                                "COLUMNS": [
                                    "price"
                                ],
                                "OPERATOR": "COLUMN_SUM",
                                "AS": "total_price"
                            }
                        }
                    ]
                }
_adc_sql_translator = PQLTranslator(pql=_adc_pql)
_adc_sql_translator.translate()
_adc_query = _adc_sql_translator.translated_pql
# Out:
# filter block
# {'FILTER_BLOCK': {'COLUMNS': ['quantity'], 'COMPARISON_OPERATOR': '>', 'VALUE': 10}}
#
#             `latest_table_fc61ab067c924b1b8080a16a042d2bb8` AS (
#                 SELECT *
#                 FROM `latest_table_c5b94cb236be47f59f70f63e3ee1fc60`
#                 WHERE `quantity` > 10
#             )
#          `quantity` > 10 AND
# filter block
# {'FILTER_BLOCK': {'COLUMNS': ['price'], 'COMPARISON_OPERATOR': '>', 'VALUE': 100}}
#
#             `latest_table_b94c18acd8ac4f368891b893c2029ac5` AS (
#                 SELECT *
#                 FROM `latest_table_fc61ab067c924b1b8080a16a042d2bb8`
#                 WHERE `price` > 100
#             )
#          `price` > 100 AND
# filter block
# {'FILTER_BLOCK': {'COLUMNS': ['date'], 'COMPARISON_OPERATOR': '>', 'VALUE': '2020-01-01'}}
#
#             `latest_table_2437c5d52d394570bf37344a2da255db` AS (
#                 SELECT *
#                 FROM `latest_table_b94c18acd8ac4f368891b893c2029ac5`
#                 WHERE `date` > '2020-01-01'
#             )
#          `date` > '2020-01-01' AND
# filter block
# {'FILTER_BLOCK': {'COLUMNS': ['date'], 'COMPARISON_OPERATOR': '<', 'VALUE': '2021-01-01'}}
#
#             `latest_table_66d6c8f1219145e7b1880a253a70dfab` AS (
#                 SELECT *
#                 FROM `latest_table_2437c5d52d394570bf37344a2da255db`
#                 WHERE `date` < '2021-01-01'
#             )
#          `date` < '2021-01-01' AND

# %%
print(_adc_query)
# Out:
# WITH
# `latest_table_c5b94cb236be47f59f70f63e3ee1fc60` AS (
# SELECT * FROM `Orders_oct_12_2024_20_00`
# ),
#
#             `latest_table_fc61ab067c924b1b8080a16a042d2bb8` AS (
#                 SELECT *
#                 FROM `latest_table_c5b94cb236be47f59f70f63e3ee1fc60`
#                 WHERE `quantity` > 10
#             )
#         ,
#             `latest_table_b94c18acd8ac4f368891b893c2029ac5` AS (
#                 SELECT *
#                 FROM `latest_table_fc61ab067c924b1b8080a16a042d2bb8`
#                 WHERE `price` > 100
#             )
#         ,
#             `latest_table_2437c5d52d394570bf37344a2da255db` AS (
#                 SELECT *
#                 FROM `latest_table_b94c18acd8ac4f368891b893c2029ac5`
#                 WHERE `date` > '2020-01-01'
#             )
#         ,
#             `latest_table_66d6c8f1219145e7b1880a253a70dfab` AS (
#                 SELECT *
#                 FROM `latest_table_2437c5d52d394570bf37344a2da255db`
#                 WHERE `date` < '2021-01-01'
#             )
#
#             SELECT SUM(`price`) AS `total_price`
#             FROM `latest_table_66d6c8f1219145e7b1880a253a70dfab`;
